# %%
import os
import sys
import json
from tqdm import tqdm_notebook as tqdm
from pprint import pprint

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
from matplotlib_venn import venn2
import seaborn as sns

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
imp_df = pd.read_csv('../mnt/importances/e020.csv')
display(imp_df.shape, imp_df.head())
# Out:
# (3470, 3)
#                       feature   importance  fold
# 0                  12 Monkeys     0.000000     0
# 1                    Air Show   412.324270     0
# 2            All Star Sorting  1219.211379     0
# 3               Balancing Act     0.000000     0
# 4  Bird Measurer (Assessment)   353.051811     0

# %%
plt.figure(figsize=(10, 20))
sns.barplot(x='importance', y='feature', data=imp_df,  order=imp_df.groupby('feature').importance.mean().sort_values(ascending=False).reset_index().feature.head(50))

# %%
imp_df[imp_df.feature.str.contains('f017')]
# Out:
#                                                 feature    importance  fold
# 659             f017_same_world_base_world_accuracy_max      0.000000     0
# 660             f017_same_world_base_world_accuracy_min      0.000000     0
# 661            f017_same_world_base_world_accuracy_mean      0.000000     0
# 662             f017_same_world_base_world_accuracy_std      0.000000     0
# 663     f017_same_world_base_world_just_before_accuracy      0.000000     0
# 664   f017_same_world_base_world_assessment_accuracy...      0.000000     0
# 665   f017_same_world_base_world_assessment_accuracy...      0.000000     0
# 666   f017_same_world_base_world_assessment_accuracy...      0.000000     0
# 667   f017_same_world_base_world_assessment_accuracy...      0.000000     0
# 668   f017_same_world_base_world_assessment_just_bef...      0.000000     0
# 669    f017_same_world_base_world_activity_accuracy_max   2587.249654     0
# 670    f017_same_world_base_world_activity_accuracy_min   2891.305430     0
# 671   f017_same_world_base_world_activity_accuracy_mean   3395.677094     0
# 672    f017_same_world_base_world_activity_accuracy_std   3092.053056     0
# 673   f017_same_world_base_world_activity_just_befor...   5547.925346     0
# 674        f017_same_world_base_world_game_accuracy_max   3257.931813     0
# 675        f017_same_world_base_world_game_accuracy_min   2571.984214     0
# 676       f017_same_world_base_world_game_accuracy_mean  14220.309976     0
# 677        f017_same_world_base_world_game_accuracy_std   2887.155172     0
# 678   f017_same_world_base_world_game_just_before_ac...   7086.626429     0
# 679        f017_same_world_base_world_game_time_max_max      9.395110     0
# 680        f017_same_world_base_world_game_time_max_min      0.000000     0
# 681       f017_same_world_base_world_game_time_max_mean     15.029449     0
# 682        f017_same_world_base_world_game_time_max_std      6.278880     0
# 683   f017_same_world_base_world_just_before_game_ti...      0.000000     0
# 684        f017_same_world_base_world_game_time_std_max      8.809230     0
# 685        f017_same_world_base_world_game_time_std_min      0.000000     0
# 686       f017_same_world_base_world_game_time_std_mean      0.000000     0
# 687        f017_same_world_base_world_game_time_std_std      8.583580     0
# 688   f017_same_world_base_world_just_before_game_ti...     16.258400     0
# 689      f017_same_world_base_world_event_count_max_max     71.285620     0
# 690      f017_same_world_base_world_event_count_max_min      0.000000     0
# 691     f017_same_world_base_world_event_count_max_mean      0.000000     0
# 692      f017_same_world_base_world_event_count_max_std      0.000000     0
# 693   f017_same_world_base_world_just_before_event_c...      9.879850     0
# 1353            f017_same_world_base_world_accuracy_max      0.000000     1
# 1354            f017_same_world_base_world_accuracy_min      0.000000     1
# 1355           f017_same_world_base_world_accuracy_mean      0.000000     1
# 1356            f017_same_world_base_world_accuracy_std      0.000000     1
# 1357    f017_same_world_base_world_just_before_accuracy      0.000000     1
# 1358  f017_same_world_base_world_assessment_accuracy...      0.000000     1
# 1359  f017_same_world_base_world_assessment_accuracy...      0.000000     1
# 1360  f017_same_world_base_world_assessment_accuracy...      0.000000     1
# 1361  f017_same_world_base_world_assessment_accuracy...      0.000000     1
# 1362  f017_same_world_base_world_assessment_just_bef...      0.000000     1
# 1363   f017_same_world_base_world_activity_accuracy_max   3276.717255     1
# 1364   f017_same_world_base_world_activity_accuracy_min   3060.116995     1
# 1365  f017_same_world_base_world_activity_accuracy_mean   3743.053805     1
# 1366   f017_same_world_base_world_activity_accuracy_std   2970.533560     1
# 1367  f017_same_world_base_world_activity_just_befor...   4940.011431     1
# 1368       f017_same_world_base_world_game_accuracy_max   2939.123502     1
# 1369       f017_same_world_base_world_game_accuracy_min   2649.332346     1
# 1370      f017_same_world_base_world_game_accuracy_mean  12155.898474     1
# 1371       f017_same_world_base_world_game_accuracy_std   2625.110858     1
# 1372  f017_same_world_base_world_game_just_before_ac...   6490.326460     1
# 1373       f017_same_world_base_world_game_time_max_max      0.000000     1
# 1374       f017_same_world_base_world_game_time_max_min      0.000000     1
# 1375      f017_same_world_base_world_game_time_max_mean     14.761310     1
# 1376       f017_same_world_base_world_game_time_max_std     17.265380     1
# 1377  f017_same_world_base_world_just_before_game_ti...      0.000000     1
# 1378       f017_same_world_base_world_game_time_std_max      9.068370     1
# 1379       f017_same_world_base_world_game_time_std_min     33.604960     1
# 1380      f017_same_world_base_world_game_time_std_mean     69.360001     1
# 1381       f017_same_world_base_world_game_time_std_std     23.014360     1
# 1382  f017_same_world_base_world_just_before_game_ti...     67.579840     1
# 1383     f017_same_world_base_world_event_count_max_max     40.826961     1
# 1384     f017_same_world_base_world_event_count_max_min      0.000000     1
# 1385    f017_same_world_base_world_event_count_max_mean     12.392780     1
# 1386     f017_same_world_base_world_event_count_max_std     30.126261     1
# 1387  f017_same_world_base_world_just_before_event_c...      0.000000     1
# 2047            f017_same_world_base_world_accuracy_max      0.000000     2
# 2048            f017_same_world_base_world_accuracy_min      0.000000     2
# 2049           f017_same_world_base_world_accuracy_mean      0.000000     2
# 2050            f017_same_world_base_world_accuracy_std      0.000000     2
# 2051    f017_same_world_base_world_just_before_accuracy      0.000000     2
# 2052  f017_same_world_base_world_assessment_accuracy...      0.000000     2
# 2053  f017_same_world_base_world_assessment_accuracy...      0.000000     2
# 2054  f017_same_world_base_world_assessment_accuracy...      0.000000     2
# 2055  f017_same_world_base_world_assessment_accuracy...      0.000000     2
# 2056  f017_same_world_base_world_assessment_just_bef...      0.000000     2
# 2057   f017_same_world_base_world_activity_accuracy_max   2598.177766     2
# 2058   f017_same_world_base_world_activity_accuracy_min   2561.200637     2
# 2059  f017_same_world_base_world_activity_accuracy_mean   3285.121059     2
# 2060   f017_same_world_base_world_activity_accuracy_std   2450.823230     2
# 2061  f017_same_world_base_world_activity_just_befor...   4594.360212     2
# 2062       f017_same_world_base_world_game_accuracy_max   3691.875275     2
# 2063       f017_same_world_base_world_game_accuracy_min   2374.453223     2
# 2064      f017_same_world_base_world_game_accuracy_mean  13886.690428     2
# 2065       f017_same_world_base_world_game_accuracy_std   2841.717568     2
# 2066  f017_same_world_base_world_game_just_before_ac...   5819.899381     2
# 2067       f017_same_world_base_world_game_time_max_max      0.000000     2
# 2068       f017_same_world_base_world_game_time_max_min      0.000000     2
# 2069      f017_same_world_base_world_game_time_max_mean      9.384980     2
# 2070       f017_same_world_base_world_game_time_max_std      0.000000     2
# 2071  f017_same_world_base_world_just_before_game_ti...      0.000000     2
# 2072       f017_same_world_base_world_game_time_std_max     15.748600     2
# 2073       f017_same_world_base_world_game_time_std_min     20.735600     2
# 2074      f017_same_world_base_world_game_time_std_mean     10.330000     2
# 2075       f017_same_world_base_world_game_time_std_std     15.859500     2
# 2076  f017_same_world_base_world_just_before_game_ti...      6.218760     2
# 2077     f017_same_world_base_world_event_count_max_max     35.234080     2
# 2078     f017_same_world_base_world_event_count_max_min      0.000000     2
# 2079    f017_same_world_base_world_event_count_max_mean      5.784750     2
# 2080     f017_same_world_base_world_event_count_max_std      0.000000     2
# 2081  f017_same_world_base_world_just_before_event_c...      0.000000     2
# 2741            f017_same_world_base_world_accuracy_max      0.000000     3
# 2742            f017_same_world_base_world_accuracy_min      0.000000     3
# 2743           f017_same_world_base_world_accuracy_mean      0.000000     3
# 2744            f017_same_world_base_world_accuracy_std      0.000000     3
# 2745    f017_same_world_base_world_just_before_accuracy      0.000000     3
# 2746  f017_same_world_base_world_assessment_accuracy...      0.000000     3
# 2747  f017_same_world_base_world_assessment_accuracy...      0.000000     3
# 2748  f017_same_world_base_world_assessment_accuracy...      0.000000     3
# 2749  f017_same_world_base_world_assessment_accuracy...      0.000000     3
# 2750  f017_same_world_base_world_assessment_just_bef...      0.000000     3
# 2751   f017_same_world_base_world_activity_accuracy_max   3346.028440     3
# 2752   f017_same_world_base_world_activity_accuracy_min   3095.770432     3
# 2753  f017_same_world_base_world_activity_accuracy_mean   4345.897693     3
# 2754   f017_same_world_base_world_activity_accuracy_std   3258.675508     3
# 2755  f017_same_world_base_world_activity_just_befor...   4079.855571     3
# 2756       f017_same_world_base_world_game_accuracy_max   3114.307922     3
# 2757       f017_same_world_base_world_game_accuracy_min   2593.454860     3
# 2758      f017_same_world_base_world_game_accuracy_mean  13275.401445     3
# 2759       f017_same_world_base_world_game_accuracy_std   3170.551208     3
# 2760  f017_same_world_base_world_game_just_before_ac...   6571.923851     3
# 2761       f017_same_world_base_world_game_time_max_max      4.510200     3
# 2762       f017_same_world_base_world_game_time_max_min      0.000000     3
# 2763      f017_same_world_base_world_game_time_max_mean     18.091960     3
# 2764       f017_same_world_base_world_game_time_max_std      0.000000     3
# 2765  f017_same_world_base_world_just_before_game_ti...      0.000000     3
# 2766       f017_same_world_base_world_game_time_std_max      0.000000     3
# 2767       f017_same_world_base_world_game_time_std_min     44.762519     3
# 2768      f017_same_world_base_world_game_time_std_mean     19.718750     3
# 2769       f017_same_world_base_world_game_time_std_std     22.532760     3
# 2770  f017_same_world_base_world_just_before_game_ti...     36.323330     3
# 2771     f017_same_world_base_world_event_count_max_max     31.836690     3
# 2772     f017_same_world_base_world_event_count_max_min      0.000000     3
# 2773    f017_same_world_base_world_event_count_max_mean      0.000000     3
# 2774     f017_same_world_base_world_event_count_max_std     34.539640     3
# 2775  f017_same_world_base_world_just_before_event_c...      0.000000     3
# 3435            f017_same_world_base_world_accuracy_max      0.000000     4
# 3436            f017_same_world_base_world_accuracy_min      0.000000     4
# 3437           f017_same_world_base_world_accuracy_mean      0.000000     4
# 3438            f017_same_world_base_world_accuracy_std      0.000000     4
# 3439    f017_same_world_base_world_just_before_accuracy      0.000000     4
# 3440  f017_same_world_base_world_assessment_accuracy...      0.000000     4
# 3441  f017_same_world_base_world_assessment_accuracy...      0.000000     4
# 3442  f017_same_world_base_world_assessment_accuracy...      0.000000     4
# 3443  f017_same_world_base_world_assessment_accuracy...      0.000000     4
# 3444  f017_same_world_base_world_assessment_just_bef...      0.000000     4
# 3445   f017_same_world_base_world_activity_accuracy_max   2983.744709     4
# 3446   f017_same_world_base_world_activity_accuracy_min   2235.758727     4
# 3447  f017_same_world_base_world_activity_accuracy_mean   2918.549109     4
# 3448   f017_same_world_base_world_activity_accuracy_std   2518.114518     4
# 3449  f017_same_world_base_world_activity_just_befor...   4422.968825     4
# 3450       f017_same_world_base_world_game_accuracy_max   2071.358827     4
# 3451       f017_same_world_base_world_game_accuracy_min   2748.293512     4
# 3452      f017_same_world_base_world_game_accuracy_mean  14478.620650     4
# 3453       f017_same_world_base_world_game_accuracy_std   2658.994348     4
# 3454  f017_same_world_base_world_game_just_before_ac...   5655.251101     4
# 3455       f017_same_world_base_world_game_time_max_max      0.000000     4
# 3456       f017_same_world_base_world_game_time_max_min      0.000000     4
# 3457      f017_same_world_base_world_game_time_max_mean      5.763660     4
# 3458       f017_same_world_base_world_game_time_max_std      7.767600     4
# 3459  f017_same_world_base_world_just_before_game_ti...      0.000000     4
# 3460       f017_same_world_base_world_game_time_std_max     16.352301     4
# 3461       f017_same_world_base_world_game_time_std_min    113.561249     4
# 3462      f017_same_world_base_world_game_time_std_mean     19.807290     4
# 3463       f017_same_world_base_world_game_time_std_std     27.260441     4
# 3464  f017_same_world_base_world_just_before_game_ti...     19.355560     4
# 3465     f017_same_world_base_world_event_count_max_max     21.234431     4
# 3466     f017_same_world_base_world_event_count_max_min      0.000000     4
# 3467    f017_same_world_base_world_event_count_max_mean      0.000000     4
# 3468     f017_same_world_base_world_event_count_max_std     21.793230     4
# 3469  f017_same_world_base_world_just_before_event_c...      0.000000     4
