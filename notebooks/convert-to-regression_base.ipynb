# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import XGBClassifier, XGBRegressor
from xgboost import plot_importance
from catboost import CatBoostRegressor
from matplotlib import pyplot
import shap

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
from time import time
from tqdm import tqdm_notebook as tqdm
from collections import Counter
from scipy import stats
import lightgbm as lgb
from sklearn.metrics import cohen_kappa_score, mean_squared_error
from sklearn.model_selection import KFold, StratifiedKFold
import gc
import json
pd.set_option('display.max_columns', 1000)
# Out:
# /kaggle/input/data-science-bowl-2019/sample_submission.csv
# /kaggle/input/data-science-bowl-2019/specs.csv
# /kaggle/input/data-science-bowl-2019/train_labels.csv
# /kaggle/input/data-science-bowl-2019/train.csv
# /kaggle/input/data-science-bowl-2019/test.csv

# %% [markdown]
# # Objective
#
# * In the last notebook we create our baseline model including a feature selection part.
# * Cohen cappa score of 0.456 (lb) with a local cv score of 0.529
# * In this notebook we are going to add more features and remove others that i think they overfitt the train set and then check if our local cv score improve.
# * Next, we will check if this improvement aligns with the lb.

# %% [markdown]
# # Notes
# * Check the distribution of the target variable of the out of folds score and the prediction distribution. A good model should more or less have the same distribution.

# %%
def eval_qwk_lgb_regr(y_true, y_pred):
    """
    Fast cappa eval function for lgb.
    """
    dist = Counter(reduce_train['accuracy_group'])
    for k in dist:
        dist[k] /= len(reduce_train)
    reduce_train['accuracy_group'].hist()
    
    acum = 0
    bound = {}
    for i in range(3):
        acum += dist[i]
        bound[i] = np.percentile(y_pred, acum * 100)

    def classify(x):
        if x <= bound[0]:
            return 0
        elif x <= bound[1]:
            return 1
        elif x <= bound[2]:
            return 2
        else:
            return 3

    y_pred = np.array(list(map(classify, y_pred))).reshape(y_true.shape)

    return 'cappa', cohen_kappa_score(y_true, y_pred, weights='quadratic'), True

# %%
def cohenkappa(ypred, y):
    y = y.get_label().astype("int")
    ypred = ypred.reshape((4, -1)).argmax(axis = 0)
    loss = cohenkappascore(y, y_pred, weights = 'quadratic')
    return "cappa", loss, True

# %%
def read_data():
    print('Reading train.csv file....')
    train = pd.read_csv('/kaggle/input/data-science-bowl-2019/train.csv')
    print('Training.csv file have {} rows and {} columns'.format(train.shape[0], train.shape[1]))

    print('Reading test.csv file....')
    test = pd.read_csv('/kaggle/input/data-science-bowl-2019/test.csv')
    print('Test.csv file have {} rows and {} columns'.format(test.shape[0], test.shape[1]))

    print('Reading train_labels.csv file....')
    train_labels = pd.read_csv('/kaggle/input/data-science-bowl-2019/train_labels.csv')
    print('Train_labels.csv file have {} rows and {} columns'.format(train_labels.shape[0], train_labels.shape[1]))

    print('Reading specs.csv file....')
    specs = pd.read_csv('/kaggle/input/data-science-bowl-2019/specs.csv')
    print('Specs.csv file have {} rows and {} columns'.format(specs.shape[0], specs.shape[1]))

    print('Reading sample_submission.csv file....')
    sample_submission = pd.read_csv('/kaggle/input/data-science-bowl-2019/sample_submission.csv')
    print('Sample_submission.csv file have {} rows and {} columns'.format(sample_submission.shape[0], sample_submission.shape[1]))
    return train, test, train_labels, specs, sample_submission

# %%
def encode_title(train, test, train_labels):
    # encode title
    train['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), train['title'], train['event_code']))
    test['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), test['title'], test['event_code']))
    all_title_event_code = list(set(train["title_event_code"].unique()).union(test["title_event_code"].unique()))
    # make a list with all the unique 'titles' from the train and test set
    list_of_user_activities = list(set(train['title'].unique()).union(set(test['title'].unique())))
    # make a list with all the unique 'event_code' from the train and test set
    list_of_event_code = list(set(train['event_code'].unique()).union(set(test['event_code'].unique())))
    list_of_event_id = list(set(train['event_id'].unique()).union(set(test['event_id'].unique())))
    # make a list with all the unique worlds from the train and test set
    list_of_worlds = list(set(train['world'].unique()).union(set(test['world'].unique())))
    # create a dictionary numerating the titles
    activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))
    activities_labels = dict(zip(np.arange(len(list_of_user_activities)), list_of_user_activities))
    activities_world = dict(zip(list_of_worlds, np.arange(len(list_of_worlds))))
    assess_titles = list(set(train[train['type'] == 'Assessment']['title'].value_counts().index).union(set(test[test['type'] == 'Assessment']['title'].value_counts().index)))
    # replace the text titles with the number titles from the dict
    train['title'] = train['title'].map(activities_map)
    test['title'] = test['title'].map(activities_map)
    train['world'] = train['world'].map(activities_world)
    test['world'] = test['world'].map(activities_world)
    train_labels['title'] = train_labels['title'].map(activities_map)
    win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
    # then, it set one element, the 'Bird Measurer (Assessment)' as 4110, 10 more than the rest
    win_code[activities_map['Bird Measurer (Assessment)']] = 4110
    # convert text into datetime
    train['timestamp'] = pd.to_datetime(train['timestamp'])
    test['timestamp'] = pd.to_datetime(test['timestamp'])
    
    
    return train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code

# %%
# this is the function that convert the raw data into processed features
def get_data(user_sample, test_set=False):
    '''
    The user_sample is a DataFrame from train or test where the only one 
    installation_id is filtered
    And the test_set parameter is related with the labels processing, that is only requered
    if test_set=False
    '''
    # Constants and parameters declaration
    last_activity = 0
    
    user_activities_count = {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
    
    # new features: time spent in each activity
    last_session_time_sec = 0
    accuracy_groups = {0:0, 1:0, 2:0, 3:0}
    all_assessments = []
    accumulated_accuracy_group = 0
    accumulated_accuracy = 0
    accumulated_correct_attempts = 0 
    accumulated_uncorrect_attempts = 0
    accumulated_actions = 0
    counter = 0
    time_first_activity = float(user_sample['timestamp'].values[0])
    durations = []
    last_accuracy_title = {'acc_' + title: -1 for title in assess_titles}
    event_code_count: Dict[str, int] = {ev: 0 for ev in list_of_event_code}
    event_id_count: Dict[str, int] = {eve: 0 for eve in list_of_event_id}
    title_count: Dict[str, int] = {eve: 0 for eve in activities_labels.values()} 
    title_event_code_count: Dict[str, int] = {t_eve: 0 for t_eve in all_title_event_code}
        
    # last features
    sessions_count = 0
    
    # itarates through each session of one instalation_id
    for i, session in user_sample.groupby('game_session', sort=False):
        # i = game_session_id
        # session is a DataFrame that contain only one game_session
        
        # get some sessions information
        session_type = session['type'].iloc[0]
        session_title = session['title'].iloc[0]
        session_title_text = activities_labels[session_title]
                    
            
        # for each assessment, and only this kind off session, the features below are processed
        # and a register are generated
        if (session_type == 'Assessment') & (test_set or len(session)>1):
            # search for event_code 4100, that represents the assessments trial
            all_attempts = session.query(f'event_code == {win_code[session_title]}')
            # then, check the numbers of wins and the number of losses
            true_attempts = all_attempts['event_data'].str.contains('true').sum()
            false_attempts = all_attempts['event_data'].str.contains('false').sum()
            # copy a dict to use as feature template, it's initialized with some itens: 
            # {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
            features = user_activities_count.copy()
            features.update(last_accuracy_title.copy())
            features.update(event_code_count.copy())
            features.update(event_id_count.copy())
            features.update(title_count.copy())
            features.update(title_event_code_count.copy())
            features.update(last_accuracy_title.copy())
            features['installation_session_count'] = sessions_count
            
            variety_features = [('var_event_code', event_code_count),
                              ('var_event_id', event_id_count),
                               ('var_title', title_count),
                               ('var_title_event_code', title_event_code_count)]
            
            for name, dict_counts in variety_features:
                arr = np.array(list(dict_counts.values()))
                features[name] = np.count_nonzero(arr)
                 
            # get installation_id for aggregated features
            features['installation_id'] = session['installation_id'].iloc[-1]
            # add title as feature, remembering that title represents the name of the game
            features['session_title'] = session['title'].iloc[0]
            # the 4 lines below add the feature of the history of the trials of this player
            # this is based on the all time attempts so far, at the moment of this assessment
            features['accumulated_correct_attempts'] = accumulated_correct_attempts
            features['accumulated_uncorrect_attempts'] = accumulated_uncorrect_attempts
            accumulated_correct_attempts += true_attempts 
            accumulated_uncorrect_attempts += false_attempts
            # the time spent in the app so far
            if durations == []:
                features['duration_mean'] = 0
                features['duration_std'] = 0
            else:
                features['duration_mean'] = np.mean(durations)
                features['duration_std'] = np.std(durations)
            durations.append((session.iloc[-1, 2] - session.iloc[0, 2] ).seconds)
            # the accurace is the all time wins divided by the all time attempts
            features['accumulated_accuracy'] = accumulated_accuracy/counter if counter > 0 else 0
            accuracy = true_attempts/(true_attempts+false_attempts) if (true_attempts+false_attempts) != 0 else 0
            accumulated_accuracy += accuracy
            last_accuracy_title['acc_' + session_title_text] = accuracy
            # a feature of the current accuracy categorized
            # it is a counter of how many times this player was in each accuracy group
            if accuracy == 0:
                features['accuracy_group'] = 0
            elif accuracy == 1:
                features['accuracy_group'] = 3
            elif accuracy == 0.5:
                features['accuracy_group'] = 2
            else:
                features['accuracy_group'] = 1
            features.update(accuracy_groups)
            accuracy_groups[features['accuracy_group']] += 1
            # mean of the all accuracy groups of this player
            features['accumulated_accuracy_group'] = accumulated_accuracy_group/counter if counter > 0 else 0
            accumulated_accuracy_group += features['accuracy_group']
            # how many actions the player has done so far, it is initialized as 0 and updated some lines below
            features['accumulated_actions'] = accumulated_actions
            
            # there are some conditions to allow this features to be inserted in the datasets
            # if it's a test set, all sessions belong to the final dataset
            # it it's a train, needs to be passed throught this clausule: session.query(f'event_code == {win_code[session_title]}')
            # that means, must exist an event_code 4100 or 4110
            if test_set:
                all_assessments.append(features)
            elif true_attempts+false_attempts > 0:
                all_assessments.append(features)
                
            counter += 1
        
        sessions_count += 1
        # this piece counts how many actions was made in each event_code so far
        def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = k
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            
        event_code_count = update_counters(event_code_count, "event_code")
        event_id_count = update_counters(event_id_count, "event_id")
        title_count = update_counters(title_count, 'title')
        title_event_code_count = update_counters(title_event_code_count, 'title_event_code')

        # counts how many actions the player has done so far, used in the feature of the same name
        accumulated_actions += len(session)
        if last_activity != session_type:
            user_activities_count[session_type] += 1
            last_activitiy = session_type 
                        
    # if it't the test_set, only the last assessment must be predicted, the previous are scraped
    if test_set:
        return all_assessments[-1]
    # in the train_set, all assessments goes to the dataset
    return all_assessments

# %%
def get_train_and_test(train, test):
    compiled_train = []
    compiled_test = []
    for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
        compiled_train += get_data(user_sample)
    for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
        test_data = get_data(user_sample, test_set = True)
        compiled_test.append(test_data)
    reduce_train = pd.DataFrame(compiled_train)
    reduce_test = pd.DataFrame(compiled_test)
    categoricals = ['session_title']
    return reduce_train, reduce_test, categoricals

# %%
class Base_Model(object):
    
    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True):
        self.train_df = train_df
        self.test_df = test_df
        self.features = features
        self.n_splits = n_splits
        self.categoricals = categoricals
        self.target = 'accuracy_group'
        self.cv = self.get_cv()
        self.verbose = verbose
        self.params = self.get_params()
        self.y_pred, self.score, self.model = self.fit()
        
    def train_model(self, train_set, val_set):
        raise NotImplementedError
        
    def get_cv(self):
        cv = StratifiedKFold(n_splits=self.n_splits, shuffle=True, random_state=42)
        return cv.split(self.train_df, self.train_df[self.target])
    
    def get_params(self):
        raise NotImplementedError
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        raise NotImplementedError
        
    def convert_x(self, x):
        return x
        
    def fit(self):
        oof_pred = np.zeros((len(reduce_train), ))
        y_pred = np.zeros((len(reduce_test), ))
        for fold, (train_idx, val_idx) in enumerate(self.cv):
            x_train, x_val = self.train_df[self.features].iloc[train_idx], self.train_df[self.features].iloc[val_idx]
            y_train, y_val = self.train_df[self.target][train_idx], self.train_df[self.target][val_idx]
            train_set, val_set = self.convert_dataset(x_train, y_train, x_val, y_val)
            model = self.train_model(train_set, val_set)
            conv_x_val = self.convert_x(x_val)
            oof_pred[val_idx] = model.predict(conv_x_val).reshape(oof_pred[val_idx].shape)
            x_test = self.convert_x(self.test_df[self.features])
            y_pred += model.predict(x_test).reshape(y_pred.shape) / self.n_splits
            print('Partial score of fold {} is: {}'.format(fold, eval_qwk_lgb_regr(y_val, oof_pred[val_idx])[1]))
        _, loss_score, _ = eval_qwk_lgb_regr(self.train_df[self.target], oof_pred)
        if self.verbose:
            print('Our oof cohen kappa score is: ', loss_score)
        return y_pred, loss_score, model

# %%
class Lgb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return lgb.train(self.params, train_set, valid_sets=[train_set, val_set], verbose_eval=verbosity)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = lgb.Dataset(x_train, y_train, categorical_feature=self.categoricals)
        val_set = lgb.Dataset(x_val, y_val, categorical_feature=self.categoricals)
        return train_set, val_set
        
    def get_params(self):
        params = {'n_estimators':5000,
                    'boosting_type': 'gbdt',
                    'objective': 'regression',
                    'metric': 'rmse',
                    'subsample': 0.75,
                    'subsample_freq': 1,
                    'learning_rate': 0.01,
                    'feature_fraction': 0.9,
                    'max_depth': 15,
                    'lambda_l1': 1,  
                    'lambda_l2': 1,
                    'early_stopping_rounds': 100
                    }
        return params

# %%
class Xgb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return xgb.train(self.params, train_set, 
                         num_boost_round=5000, evals=[(train_set, 'train'), (val_set, 'val')], 
                         verbose_eval=verbosity, early_stopping_rounds=100)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = xgb.DMatrix(x_train, y_train)
        val_set = xgb.DMatrix(x_val, y_val)
        return train_set, val_set
    
    def convert_x(self, x):
        return xgb.DMatrix(x)
        
    def get_params(self):
        params = {'colsample_bytree': 0.8,                 
            'learning_rate': 0.01,
            'max_depth': 10,
            'subsample': 1,
            'objective':'reg:squarederror',
            #'eval_metric':'rmse',
            'min_child_weight':3,
            'gamma':0.25,
            'n_estimators':5000}

        return params

# %%
class Catb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        clf = CatBoostRegressor(**self.params)
        clf.fit(train_set['X'], 
                train_set['y'], 
                eval_set=(val_set['X'], val_set['y']),
                verbose=verbosity, 
                cat_features=self.categoricals)
        return clf
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = {'X': x_train, 'y': y_train}
        val_set = {'X': x_val, 'y': y_val}
        return train_set, val_set
        
    def get_params(self):
        params = {'loss_function': 'RMSE',
                   'task_type': "CPU",
                   'iterations': 5000,
                   'od_type': "Iter",
                    'depth': 10,
                  'colsample_bylevel': 0.5, 
                   'early_stopping_rounds': 300,
                    'l2_leaf_reg': 18,
                   'random_seed': 42,
                    'use_best_model': True
                    }
        return params

# %%
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder

class Nn_Model(Base_Model):
    
    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True):
        features = features.copy()
        if len(categoricals) > 0:
            for cat in categoricals:
                enc = OneHotEncoder()
                train_cats = enc.fit_transform(train_df[[cat]])
                test_cats = enc.transform(test_df[[cat]])
                cat_cols = ['{}_{}'.format(cat, str(col)) for col in enc.active_features_]
                features += cat_cols
                train_cats = pd.DataFrame(train_cats.toarray(), columns=cat_cols)
                test_cats = pd.DataFrame(test_cats.toarray(), columns=cat_cols)
                train_df = pd.concat([train_df, train_cats], axis=1)
                test_df = pd.concat([test_df, test_cats], axis=1)
        scalar = MinMaxScaler()
        train_df[features] = scalar.fit_transform(train_df[features])
        test_df[features] = scalar.transform(test_df[features])
        print(train_df[features].shape)
        super().__init__(train_df, test_df, features, categoricals, n_splits, verbose)
        
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        model = tf.keras.models.Sequential([
            tf.keras.layers.Input(shape=(train_set['X'].shape[1],)),
            tf.keras.layers.Dense(200, activation='relu'),
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(100, activation='relu'),
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(50, activation='relu'),
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(25, activation='relu'),
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(1, activation='relu')
        ])
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=4e-4), loss='mse')
        print(model.summary())
        save_best = tf.keras.callbacks.ModelCheckpoint('nn_model.w8', save_weights_only=True, save_best_only=True, verbose=1)
        early_stop = tf.keras.callbacks.EarlyStopping(patience=20)
        model.fit(train_set['X'], 
                train_set['y'], 
                validation_data=(val_set['X'], val_set['y']),
                epochs=100,
                 callbacks=[save_best, early_stop])
        model.load_weights('nn_model.w8')
        return model
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = {'X': x_train, 'y': y_train}
        val_set = {'X': x_val, 'y': y_val}
        return train_set, val_set
        
    def get_params(self):
        return None

# %%
from random import choice

class Cnn_Model(Base_Model):
    
    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True):
        features = features.copy()
        if len(categoricals) > 0:
            for cat in categoricals:
                enc = OneHotEncoder()
                train_cats = enc.fit_transform(train_df[[cat]])
                test_cats = enc.transform(test_df[[cat]])
                cat_cols = ['{}_{}'.format(cat, str(col)) for col in enc.active_features_]
                features += cat_cols
                train_cats = pd.DataFrame(train_cats.toarray(), columns=cat_cols)
                test_cats = pd.DataFrame(test_cats.toarray(), columns=cat_cols)
                train_df = pd.concat([train_df, train_cats], axis=1)
                test_df = pd.concat([test_df, test_cats], axis=1)
        scalar = MinMaxScaler()
        train_df[features] = scalar.fit_transform(train_df[features])
        test_df[features] = scalar.transform(test_df[features])
        self.create_feat_2d(features)
        super().__init__(train_df, test_df, features, categoricals, n_splits, verbose)
        
    def create_feat_2d(self, features, n_feats_repeat=50):
        self.n_feats = len(features)
        self.n_feats_repeat = n_feats_repeat
        self.mask = np.zeros((self.n_feats_repeat, self.n_feats), dtype=np.int32)
        for i in range(self.n_feats_repeat):
            l = list(range(self.n_feats))
            for j in range(self.n_feats):
                c = l.pop(choice(range(len(l))))
                self.mask[i, j] = c
        self.mask = tf.convert_to_tensor(self.mask)
        print(self.mask.shape)
       
        
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0

        inp = tf.keras.layers.Input(shape=(self.n_feats))
        x = tf.keras.layers.Lambda(lambda x: tf.gather(x, self.mask, axis=1))(inp)
        x = tf.keras.layers.Reshape((self.n_feats_repeat, self.n_feats, 1))(x)
        x = tf.keras.layers.Conv2D(18, (50, 50), strides=50, activation='relu')(x)
        x = tf.keras.layers.Flatten()(x)
        #x = tf.keras.layers.Dense(200, activation='relu')(x)
        #x = tf.keras.layers.LayerNormalization()(x)
        #x = tf.keras.layers.Dropout(0.3)(x)
        x = tf.keras.layers.Dense(100, activation='relu')(x)
        x = tf.keras.layers.LayerNormalization()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
        x = tf.keras.layers.Dense(50, activation='relu')(x)
        x = tf.keras.layers.LayerNormalization()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
        out = tf.keras.layers.Dense(1)(x)
        
        model = tf.keras.Model(inp, out)
    
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='mse')
        print(model.summary())
        save_best = tf.keras.callbacks.ModelCheckpoint('nn_model.w8', save_weights_only=True, save_best_only=True, verbose=1)
        early_stop = tf.keras.callbacks.EarlyStopping(patience=20)
        model.fit(train_set['X'], 
                train_set['y'], 
                validation_data=(val_set['X'], val_set['y']),
                epochs=100,
                 callbacks=[save_best, early_stop])
        model.load_weights('nn_model.w8')
        return model
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = {'X': x_train, 'y': y_train}
        val_set = {'X': x_val, 'y': y_val}
        return train_set, val_set
        
    def get_params(self):
        return None

# %%
# read data
train, test, train_labels, specs, sample_submission = read_data()
# get usefull dict with maping encode
train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code = encode_title(train, test, train_labels)
# tranform function to get the train and test set
reduce_train, reduce_test, categoricals = get_train_and_test(train, test)
# Out:
# Reading train.csv file....
# Training.csv file have 11341042 rows and 11 columns
# Reading test.csv file....
# Test.csv file have 1156414 rows and 11 columns
# Reading train_labels.csv file....
# Train_labels.csv file have 17690 rows and 7 columns
# Reading specs.csv file....
# Specs.csv file have 386 rows and 3 columns
# Reading sample_submission.csv file....
# Sample_submission.csv file have 1000 rows and 2 columns
# HBox(children=(IntProgress(value=0, max=17000), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
def stract_hists(feature, train=reduce_train, test=reduce_test, adjust=False, plot=False):
    n_bins = 10
    train_data = train[feature]
    test_data = test[feature]
    if adjust:
        test_data *= train_data.mean() / test_data.mean()
    perc_90 = np.percentile(train_data, 95)
    train_data = np.clip(train_data, 0, perc_90)
    test_data = np.clip(test_data, 0, perc_90)
    train_hist = np.histogram(train_data, bins=n_bins)[0] / len(train_data)
    test_hist = np.histogram(test_data, bins=n_bins)[0] / len(test_data)
    msre = mean_squared_error(train_hist, test_hist)
    if plot:
        print(msre)
        plt.bar(range(n_bins), train_hist, color='blue', alpha=0.5)
        plt.bar(range(n_bins), test_hist, color='red', alpha=0.5)
        plt.show()
    return msre
stract_hists('Magma Peak - Level 1_2000', adjust=False, plot=True)
# Out:
# 0.0026939774600629332
# 0.0026939774600629332

# %%
# call feature engineering function
features = reduce_train.loc[(reduce_train.sum(axis=1) != 0), (reduce_train.sum(axis=0) != 0)].columns # delete useless columns
features = [x for x in features if x not in ['accuracy_group', 'installation_id']]

# %%
counter = 0
to_remove = []
for feat_a in features:
    for feat_b in features:
        if feat_a != feat_b and feat_a not in to_remove and feat_b not in to_remove:
            c = np.corrcoef(reduce_train[feat_a], reduce_train[feat_b])[0][1]
            if c > 0.99:
                counter += 1
                to_remove.append(feat_b)
                print('{}: FEAT_A: {} FEAT_B: {} - Correlation: {}'.format(counter, feat_a, feat_b, c))
# Out:
# 1: FEAT_A: Clip FEAT_B: 27253bdc - Correlation: 1.0
# 2: FEAT_A: 2050 FEAT_B: 2040 - Correlation: 0.9965259434878119
# 3: FEAT_A: 2050 FEAT_B: 5a848010 - Correlation: 0.9923551438502285
# 4: FEAT_A: 2050 FEAT_B: 37c53127 - Correlation: 0.9999999999999998
# 5: FEAT_A: 2050 FEAT_B: 73757a5e - Correlation: 0.9998050146713994
# 6: FEAT_A: 2050 FEAT_B: dcaede90 - Correlation: 0.9965259434878119
# 7: FEAT_A: 2050 FEAT_B: f71c4741 - Correlation: 0.9904123162598565
# 8: FEAT_A: 2050 FEAT_B: 2b9272f4 - Correlation: 0.9999839030068788
# 9: FEAT_A: 2050 FEAT_B: 08fd73f3 - Correlation: 0.9966123918733647
# 10: FEAT_A: 2050 FEAT_B: 26fd2d99 - Correlation: 0.9965084543995756
# 11: FEAT_A: 2050 FEAT_B: f7e47413 - Correlation: 0.990218729236375
# 12: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_3021 - Correlation: 0.9998050146713994
# 13: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_3121 - Correlation: 0.9999839030068788
# 14: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2080 - Correlation: 0.9923551438502285
# 15: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_3010 - Correlation: 0.9904123162598565
# 16: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2050 - Correlation: 0.9999999999999998
# 17: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2020 - Correlation: 0.9965084543995756
# 18: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_3110 - Correlation: 0.990218729236375
# 19: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2030 - Correlation: 0.9966123918733647
# 20: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2040 - Correlation: 0.9965259434878119
# 21: FEAT_A: 4230 FEAT_B: 4235 - Correlation: 0.9999995197498742
# 22: FEAT_A: 4230 FEAT_B: ad148f58 - Correlation: 0.9999999999999998
# 23: FEAT_A: 4230 FEAT_B: 85de926c - Correlation: 0.9999995197498742
# 24: FEAT_A: 4230 FEAT_B: Bubble Bath_4235 - Correlation: 0.9999995197498742
# 25: FEAT_A: 4230 FEAT_B: Bubble Bath_4230 - Correlation: 0.9999999999999998
# 26: FEAT_A: 5000 FEAT_B: 5010 - Correlation: 0.9991849213605325
# 27: FEAT_A: 5000 FEAT_B: a6d66e51 - Correlation: 1.0
# 28: FEAT_A: 5000 FEAT_B: 71e712d8 - Correlation: 0.9991849213605325
# 29: FEAT_A: 5000 FEAT_B: Watering Hole (Activity)_5000 - Correlation: 1.0
# 30: FEAT_A: 5000 FEAT_B: Watering Hole (Activity)_5010 - Correlation: 0.9991849213605325
# 31: FEAT_A: 4110 FEAT_B: e37a2b78 - Correlation: 0.9916265461669503
# 32: FEAT_A: 4110 FEAT_B: 17113b36 - Correlation: 0.9921889179807464
# 33: FEAT_A: 4110 FEAT_B: Bird Measurer (Assessment)_4110 - Correlation: 0.9921889179807464
# 34: FEAT_A: 4110 FEAT_B: Bird Measurer (Assessment)_3120 - Correlation: 0.9916265461669503
# 35: FEAT_A: 3110 FEAT_B: 3010 - Correlation: 0.9999293402893734
# 36: FEAT_A: 3120 FEAT_B: 3020 - Correlation: 0.9998761417908977
# 37: FEAT_A: 3121 FEAT_B: 3021 - Correlation: 0.9999098200487938
# 38: FEAT_A: 4031 FEAT_B: 74e5f8a7 - Correlation: 0.9925006482606769
# 39: FEAT_A: 4031 FEAT_B: 1996c610 - Correlation: 1.0
# 40: FEAT_A: 4031 FEAT_B: Dino Drink_4020 - Correlation: 0.9925006482606769
# 41: FEAT_A: 4031 FEAT_B: Dino Drink_4031 - Correlation: 1.0
# 42: FEAT_A: 2000 FEAT_B: installation_session_count - Correlation: 1.0
# 43: FEAT_A: 4050 FEAT_B: a1192f43 - Correlation: 1.0
# 44: FEAT_A: 4050 FEAT_B: Crystals Rule_4050 - Correlation: 1.0
# 45: FEAT_A: 2020 FEAT_B: 2030 - Correlation: 0.9959933262816538
# 46: FEAT_A: 4220 FEAT_B: 1340b8d7 - Correlation: 1.0
# 47: FEAT_A: 4220 FEAT_B: Bubble Bath_4220 - Correlation: 1.0
# 48: FEAT_A: 5d042115 FEAT_B: Flower Waterer (Activity)_4030 - Correlation: 0.9999999999999999
# 49: FEAT_A: d3640339 FEAT_B: Dino Dive_4090 - Correlation: 1.0
# 50: FEAT_A: 25fa8af4 FEAT_B: Mushroom Sorter (Assessment)_4100 - Correlation: 0.9999999999999999
# 51: FEAT_A: 0086365d FEAT_B: Pan Balance_4010 - Correlation: 1.0
# 52: FEAT_A: 0db6d71d FEAT_B: Chest Sorter (Assessment)_4020 - Correlation: 1.0
# 53: FEAT_A: d122731b FEAT_B: Cart Balancer (Assessment)_4100 - Correlation: 1.0
# 54: FEAT_A: 3afb49e6 FEAT_B: 38074c54 - Correlation: 0.9939317505039561
# 55: FEAT_A: 3afb49e6 FEAT_B: 222660ff - Correlation: 0.9939317505039561
# 56: FEAT_A: 3afb49e6 FEAT_B: e4f1efe6 - Correlation: 0.9985179906980803
# 57: FEAT_A: 3afb49e6 FEAT_B: Chest Sorter (Assessment)_2030 - Correlation: 0.9939317505039561
# 58: FEAT_A: 3afb49e6 FEAT_B: Chest Sorter (Assessment)_2010 - Correlation: 0.9939317505039561
# 59: FEAT_A: 3afb49e6 FEAT_B: Chest Sorter (Assessment)_3021 - Correlation: 1.0
# 60: FEAT_A: 3afb49e6 FEAT_B: Chest Sorter (Assessment)_3121 - Correlation: 0.9985179906980803
# 61: FEAT_A: a76029ee FEAT_B: Bird Measurer (Assessment)_4040 - Correlation: 1.0
# 62: FEAT_A: c2baf0bd FEAT_B: 36fa3ebe - Correlation: 0.9920332573725932
# 63: FEAT_A: c2baf0bd FEAT_B: c7fe2a55 - Correlation: 0.9919979663587951
# 64: FEAT_A: c2baf0bd FEAT_B: Happy Camel_2020 - Correlation: 1.0
# 65: FEAT_A: c2baf0bd FEAT_B: Happy Camel_2030 - Correlation: 0.9920332573725932
# 66: FEAT_A: c2baf0bd FEAT_B: Happy Camel_3021 - Correlation: 0.9919979663587951
# 67: FEAT_A: 90d848e0 FEAT_B: Cauldron Filler (Assessment)_2000 - Correlation: 0.9999999999999999
# 68: FEAT_A: 91561152 FEAT_B: Cauldron Filler (Assessment)_4025 - Correlation: 1.0
# 69: FEAT_A: bd612267 FEAT_B: Chest Sorter (Assessment)_4070 - Correlation: 0.9999999999999999
# 70: FEAT_A: 1f19558b FEAT_B: ca11f653 - Correlation: 0.9983164273410821
# 71: FEAT_A: 1f19558b FEAT_B: daac11b0 - Correlation: 0.9991356096406653
# 72: FEAT_A: 1f19558b FEAT_B: All Star Sorting_3121 - Correlation: 1.0
# 73: FEAT_A: 1f19558b FEAT_B: All Star Sorting_3021 - Correlation: 0.9991356096406653
# 74: FEAT_A: 1f19558b FEAT_B: All Star Sorting_2030 - Correlation: 0.9983164273410821
# 75: FEAT_A: 46b50ba8 FEAT_B: Happy Camel_4095 - Correlation: 1.0
# 76: FEAT_A: 5290eab1 FEAT_B: 04df9b66 - Correlation: 0.9998190477466216
# 77: FEAT_A: 5290eab1 FEAT_B: Cauldron Filler (Assessment)_3120 - Correlation: 1.0
# 78: FEAT_A: 5290eab1 FEAT_B: Cauldron Filler (Assessment)_3020 - Correlation: 0.9998190477466216
# 79: FEAT_A: 1c178d24 FEAT_B: a592d54e - Correlation: 0.9973125883100834
# 80: FEAT_A: 1c178d24 FEAT_B: cf7638f3 - Correlation: 0.9996196393003267
# 81: FEAT_A: 1c178d24 FEAT_B: 250513af - Correlation: 0.9999803429610498
# 82: FEAT_A: 1c178d24 FEAT_B: Pan Balance_3121 - Correlation: 0.9996196393003267
# 83: FEAT_A: 1c178d24 FEAT_B: Pan Balance_2030 - Correlation: 1.0
# 84: FEAT_A: 1c178d24 FEAT_B: Pan Balance_3021 - Correlation: 0.9999803429610498
# 85: FEAT_A: 1c178d24 FEAT_B: Pan Balance_2020 - Correlation: 0.9973125883100834
# 86: FEAT_A: 37db1c2f FEAT_B: Happy Camel_4045 - Correlation: 1.0
# 87: FEAT_A: 8fee50e2 FEAT_B: Bird Measurer (Assessment)_4020 - Correlation: 1.0
# 88: FEAT_A: c58186bf FEAT_B: Sandcastle Builder (Activity)_4035 - Correlation: 1.0
# 89: FEAT_A: abc5811c FEAT_B: Happy Camel_4010 - Correlation: 1.0
# 90: FEAT_A: 4901243f FEAT_B: Fireworks (Activity)_2000 - Correlation: 1.0
# 91: FEAT_A: c189aaf2 FEAT_B: Happy Camel_2083 - Correlation: 1.0
# 92: FEAT_A: 6cf7d25c FEAT_B: 15f99afc - Correlation: 0.9994848234397951
# 93: FEAT_A: 6cf7d25c FEAT_B: Pan Balance_3110 - Correlation: 0.9994848234397951
# 94: FEAT_A: 6cf7d25c FEAT_B: Pan Balance_3010 - Correlation: 1.0
# 95: FEAT_A: 2a512369 FEAT_B: 33505eae - Correlation: 0.9994585292841967
# 96: FEAT_A: 2a512369 FEAT_B: Leaf Leader_3010 - Correlation: 0.9994585292841967
# 97: FEAT_A: 2a512369 FEAT_B: Leaf Leader_3110 - Correlation: 1.0
# 98: FEAT_A: 26a5a3dd FEAT_B: All Star Sorting_4080 - Correlation: 0.9999999999999999
# 99: FEAT_A: 67aa2ada FEAT_B: Leaf Leader_4090 - Correlation: 1.0
# 100: FEAT_A: 65abac75 FEAT_B: Air Show_4010 - Correlation: 0.9999999999999999
# 101: FEAT_A: 28a4eb9a FEAT_B: 9de5e594 - Correlation: 0.9995923561196802
# 102: FEAT_A: 28a4eb9a FEAT_B: Dino Dive_3120 - Correlation: 1.0
# 103: FEAT_A: 28a4eb9a FEAT_B: Dino Dive_3020 - Correlation: 0.9995923561196802
# 104: FEAT_A: 857f21c0 FEAT_B: Bubble Bath_4040 - Correlation: 1.0
# 105: FEAT_A: d51b1749 FEAT_B: Happy Camel_2080 - Correlation: 0.9999999999999998
# 106: FEAT_A: 02a42007 FEAT_B: Fireworks (Activity)_4030 - Correlation: 1.0
# 107: FEAT_A: 3323d7e9 FEAT_B: 7cf1bc53 - Correlation: 0.9987451849599019
# 108: FEAT_A: 3323d7e9 FEAT_B: 3ddc79c3 - Correlation: 0.9998606654761345
# 109: FEAT_A: 3323d7e9 FEAT_B: 5154fc30 - Correlation: 0.9951634272813502
# 110: FEAT_A: 3323d7e9 FEAT_B: 86c924c4 - Correlation: 0.9930332315156457
# 111: FEAT_A: 3323d7e9 FEAT_B: e720d930 - Correlation: 0.9998454394844459
# 112: FEAT_A: 3323d7e9 FEAT_B: 3babcb9b - Correlation: 0.9952332162875027
# 113: FEAT_A: 3323d7e9 FEAT_B: Crystals Rule_3021 - Correlation: 0.9998606654761345
# 114: FEAT_A: 3323d7e9 FEAT_B: Crystals Rule_4020 - Correlation: 0.9930332315156457
# 115: FEAT_A: 3323d7e9 FEAT_B: Crystals Rule_2030 - Correlation: 1.0
# 116: FEAT_A: 3323d7e9 FEAT_B: Crystals Rule_3121 - Correlation: 0.9998454394844459
# 117: FEAT_A: 3323d7e9 FEAT_B: Crystals Rule_3110 - Correlation: 0.9952332162875027
# 118: FEAT_A: 3323d7e9 FEAT_B: Crystals Rule_3010 - Correlation: 0.9951634272813502
# 119: FEAT_A: 3323d7e9 FEAT_B: Crystals Rule_2020 - Correlation: 0.9987451849599019
# 120: FEAT_A: 7372e1a5 FEAT_B: Chow Time_4070 - Correlation: 0.9999999999999999
# 121: FEAT_A: 3bf1cf26 FEAT_B: 1af8be29 - Correlation: 0.9998900847287066
# 122: FEAT_A: 3bf1cf26 FEAT_B: Happy Camel_3120 - Correlation: 0.9999999999999999
# 123: FEAT_A: 3bf1cf26 FEAT_B: Happy Camel_3020 - Correlation: 0.9998900847287066
# 124: FEAT_A: 9d4e7b25 FEAT_B: Cart Balancer (Assessment)_4040 - Correlation: 1.0
# 125: FEAT_A: ecc6157f FEAT_B: Cart Balancer (Assessment)_4080 - Correlation: 0.9999999999999999
# 126: FEAT_A: 9554a50b FEAT_B: Cauldron Filler (Assessment)_4080 - Correlation: 0.9999999999999999
# 127: FEAT_A: 9ee1c98c FEAT_B: Sandcastle Builder (Activity)_4021 - Correlation: 1.0
# 128: FEAT_A: 37937459 FEAT_B: Sandcastle Builder (Activity)_4090 - Correlation: 1.0
# 129: FEAT_A: f93fc684 FEAT_B: 7d093bf9 - Correlation: 0.9916710892741638
# 130: FEAT_A: f93fc684 FEAT_B: Chow Time_4010 - Correlation: 1.0
# 131: FEAT_A: f93fc684 FEAT_B: Chow Time_2000 - Correlation: 0.9916710892741638
# 132: FEAT_A: 3afde5dd FEAT_B: b012cd7f - Correlation: 0.9999689260314962
# 133: FEAT_A: 3afde5dd FEAT_B: e5c9df6f - Correlation: 0.9990910601838003
# 134: FEAT_A: 3afde5dd FEAT_B: Leaf Leader_3021 - Correlation: 1.0
# 135: FEAT_A: 3afde5dd FEAT_B: Leaf Leader_3121 - Correlation: 0.9990910601838003
# 136: FEAT_A: 3afde5dd FEAT_B: Leaf Leader_2030 - Correlation: 0.9999689260314962
# 137: FEAT_A: 88d4a5be FEAT_B: 160654fd - Correlation: 0.9989297172615899
# 138: FEAT_A: 88d4a5be FEAT_B: Mushroom Sorter (Assessment)_3020 - Correlation: 0.9989297172615899
# 139: FEAT_A: 88d4a5be FEAT_B: Mushroom Sorter (Assessment)_3120 - Correlation: 1.0
# 140: FEAT_A: 709b1251 FEAT_B: 7961e599 - Correlation: 0.995000488193363
# 141: FEAT_A: 709b1251 FEAT_B: e3ff61fb - Correlation: 0.9995444786291268
# 142: FEAT_A: 709b1251 FEAT_B: Dino Dive_2020 - Correlation: 0.995000488193363
# 143: FEAT_A: 709b1251 FEAT_B: Dino Dive_3121 - Correlation: 1.0
# 144: FEAT_A: 709b1251 FEAT_B: Dino Dive_3021 - Correlation: 0.9995444786291268
# 145: FEAT_A: 392e14df FEAT_B: Cauldron Filler (Assessment)_4100 - Correlation: 1.0
# 146: FEAT_A: cfbd47c8 FEAT_B: 0330ab6a - Correlation: 0.9924528356578103
# 147: FEAT_A: cfbd47c8 FEAT_B: 4ef8cdd3 - Correlation: 0.994192647058833
# 148: FEAT_A: cfbd47c8 FEAT_B: 2230fab4 - Correlation: 0.9929106009952481
# 149: FEAT_A: cfbd47c8 FEAT_B: Chow Time_4030 - Correlation: 1.0
# 150: FEAT_A: cfbd47c8 FEAT_B: Chow Time_3020 - Correlation: 0.9924528356578103
# 151: FEAT_A: cfbd47c8 FEAT_B: Chow Time_4020 - Correlation: 0.994192647058833
# 152: FEAT_A: cfbd47c8 FEAT_B: Chow Time_3120 - Correlation: 0.9929106009952481
# 153: FEAT_A: b2dba42b FEAT_B: 1bb5fbdb - Correlation: 0.9999521729413301
# 154: FEAT_A: b2dba42b FEAT_B: Sandcastle Builder (Activity)_3110 - Correlation: 0.9999521729413301
# 155: FEAT_A: b2dba42b FEAT_B: Sandcastle Builder (Activity)_3010 - Correlation: 1.0
# 156: FEAT_A: 6088b756 FEAT_B: Dino Dive_2070 - Correlation: 1.0
# 157: FEAT_A: c277e121 FEAT_B: d45ed6a1 - Correlation: 0.9979692879543328
# 158: FEAT_A: c277e121 FEAT_B: b120f2ac - Correlation: 0.9999983835744556
# 159: FEAT_A: c277e121 FEAT_B: All Star Sorting_3020 - Correlation: 1.0
# 160: FEAT_A: c277e121 FEAT_B: All Star Sorting_3120 - Correlation: 0.9979692879543328
# 161: FEAT_A: c277e121 FEAT_B: All Star Sorting_2025 - Correlation: 0.9999983835744556
# 162: FEAT_A: e79f3763 FEAT_B: Bug Measurer (Activity)_4030 - Correlation: 1.0
# 163: FEAT_A: 0413e89d FEAT_B: c54cf6c5 - Correlation: 0.9916757107652855
# 164: FEAT_A: 0413e89d FEAT_B: 8f094001 - Correlation: 0.9924472538795667
# 165: FEAT_A: 0413e89d FEAT_B: 1beb320a - Correlation: 0.9940298541531531
# 166: FEAT_A: 0413e89d FEAT_B: 3bb91dda - Correlation: 0.991720484549911
# 167: FEAT_A: 0413e89d FEAT_B: 15eb4a7d - Correlation: 0.9997266832893074
# 168: FEAT_A: 0413e89d FEAT_B: Bubble Bath_4020 - Correlation: 0.991720484549911
# 169: FEAT_A: 0413e89d FEAT_B: Bubble Bath_3110 - Correlation: 0.9997266832893074
# 170: FEAT_A: 0413e89d FEAT_B: Bubble Bath_2020 - Correlation: 0.9940298541531531
# 171: FEAT_A: 0413e89d FEAT_B: Bubble Bath_3010 - Correlation: 1.0
# 172: FEAT_A: 0413e89d FEAT_B: Bubble Bath_2025 - Correlation: 0.9916757107652855
# 173: FEAT_A: 0413e89d FEAT_B: Bubble Bath_4045 - Correlation: 0.9924472538795667
# 174: FEAT_A: bb3e370b FEAT_B: Bottle Filler (Activity) - Correlation: 0.9950043311420309
# 175: FEAT_A: bb3e370b FEAT_B: Bottle Filler (Activity)_4030 - Correlation: 0.9999999999999999
# 176: FEAT_A: 3393b68b FEAT_B: Bird Measurer (Assessment)_2010 - Correlation: 1.0
# 177: FEAT_A: c51d8688 FEAT_B: 907a054b - Correlation: 0.9999667370361695
# 178: FEAT_A: c51d8688 FEAT_B: Pan Balance_3020 - Correlation: 0.9999667370361695
# 179: FEAT_A: c51d8688 FEAT_B: Pan Balance_3120 - Correlation: 1.0
# 180: FEAT_A: b80e5e84 FEAT_B: 7ab78247 - Correlation: 0.999833659028109
# 181: FEAT_A: b80e5e84 FEAT_B: Egg Dropper (Activity)_3110 - Correlation: 0.9999999999999998
# 182: FEAT_A: b80e5e84 FEAT_B: Egg Dropper (Activity)_3010 - Correlation: 0.999833659028109
# 183: FEAT_A: 51102b85 FEAT_B: Bird Measurer (Assessment)_4030 - Correlation: 1.0
# 184: FEAT_A: 44cb4907 FEAT_B: 8b757ab8 - Correlation: 0.9998350587947098
# 185: FEAT_A: 44cb4907 FEAT_B: Crystals Rule_3020 - Correlation: 1.0
# 186: FEAT_A: 44cb4907 FEAT_B: Crystals Rule_3120 - Correlation: 0.9998350587947098
# 187: FEAT_A: 69fdac0a FEAT_B: 8d7e386c - Correlation: 0.9996590210382708
# 188: FEAT_A: 69fdac0a FEAT_B: Happy Camel_3110 - Correlation: 1.0
# 189: FEAT_A: 69fdac0a FEAT_B: Happy Camel_3010 - Correlation: 0.9996590210382708
# 190: FEAT_A: 15a43e5b FEAT_B: Bottle Filler (Activity)_4070 - Correlation: 1.0
# 191: FEAT_A: f5b8c21a FEAT_B: 58a0de5c - Correlation: 0.9977888184537717
# 192: FEAT_A: f5b8c21a FEAT_B: 9b4001e4 - Correlation: 0.9976837802056775
# 193: FEAT_A: f5b8c21a FEAT_B: Air Show_3121 - Correlation: 0.9977888184537717
# 194: FEAT_A: f5b8c21a FEAT_B: Air Show_2030 - Correlation: 1.0
# 195: FEAT_A: f5b8c21a FEAT_B: Air Show_3021 - Correlation: 0.9976837802056775
# 196: FEAT_A: e9c52111 FEAT_B: b7530680 - Correlation: 0.9988176899646234
# 197: FEAT_A: e9c52111 FEAT_B: df4940d3 - Correlation: 0.9902482862009899
# 198: FEAT_A: e9c52111 FEAT_B: 90efca10 - Correlation: 0.9942493558520803
# 199: FEAT_A: e9c52111 FEAT_B: Bottle Filler (Activity)_4020 - Correlation: 0.9942493558520803
# 200: FEAT_A: e9c52111 FEAT_B: Bottle Filler (Activity)_3110 - Correlation: 0.9902482862009899
# 201: FEAT_A: e9c52111 FEAT_B: Bottle Filler (Activity)_2020 - Correlation: 0.9988176899646234
# 202: FEAT_A: e9c52111 FEAT_B: Bottle Filler (Activity)_2030 - Correlation: 1.0
# 203: FEAT_A: d38c2fd7 FEAT_B: Bird Measurer (Assessment)_4035 - Correlation: 1.0
# 204: FEAT_A: ea321fb1 FEAT_B: 84b0e0c8 - Correlation: 0.9993007600205117
# 205: FEAT_A: ea321fb1 FEAT_B: Chicken Balancer (Activity)_3110 - Correlation: 0.9993007600205117
# 206: FEAT_A: ea321fb1 FEAT_B: Chicken Balancer (Activity)_3010 - Correlation: 1.0
# 207: FEAT_A: 08ff79ad FEAT_B: Egg Dropper (Activity)_4090 - Correlation: 0.9999999999999999
# 208: FEAT_A: 804ee27f FEAT_B: 2a444e03 - Correlation: 0.9947207725371415
# 209: FEAT_A: 804ee27f FEAT_B: Pan Balance_4030 - Correlation: 0.9947207725371415
# 210: FEAT_A: 804ee27f FEAT_B: Pan Balance_4020 - Correlation: 1.0
# 211: FEAT_A: 83c6c409 FEAT_B: c74f40cd - Correlation: 0.9963987221516333
# 212: FEAT_A: 83c6c409 FEAT_B: 28ed704e - Correlation: 0.9996646794414055
# 213: FEAT_A: 83c6c409 FEAT_B: 9d29771f - Correlation: 0.9963745894369904
# 214: FEAT_A: 83c6c409 FEAT_B: 3dfd4aa4 - Correlation: 0.9999970893851738
# 215: FEAT_A: 83c6c409 FEAT_B: Mushroom Sorter (Assessment)_4025 - Correlation: 0.9996646794414055
# 216: FEAT_A: 83c6c409 FEAT_B: Mushroom Sorter (Assessment)_2035 - Correlation: 1.0
# 217: FEAT_A: 83c6c409 FEAT_B: Mushroom Sorter (Assessment)_2020 - Correlation: 0.9999970893851738
# 218: FEAT_A: 83c6c409 FEAT_B: Mushroom Sorter (Assessment)_3021 - Correlation: 0.9963745894369904
# 219: FEAT_A: 83c6c409 FEAT_B: Mushroom Sorter (Assessment)_3121 - Correlation: 0.9963987221516333
# 220: FEAT_A: 022b4259 FEAT_B: Bug Measurer (Activity)_4025 - Correlation: 0.9999999999999998
# 221: FEAT_A: 070a5291 FEAT_B: Bird Measurer (Assessment)_4100 - Correlation: 0.9999999999999999
# 222: FEAT_A: e080a381 FEAT_B: Pan Balance_4090 - Correlation: 1.0
# 223: FEAT_A: 5e812b27 FEAT_B: Sandcastle Builder (Activity)_4030 - Correlation: 1.0
# 224: FEAT_A: ecaab346 FEAT_B: b2e5b0f1 - Correlation: 0.9998494646045045
# 225: FEAT_A: ecaab346 FEAT_B: b74258a0 - Correlation: 1.0
# 226: FEAT_A: ecaab346 FEAT_B: Cart Balancer (Assessment)_2030 - Correlation: 1.0
# 227: FEAT_A: ecaab346 FEAT_B: Cart Balancer (Assessment)_2010 - Correlation: 0.9998494646045045
# 228: FEAT_A: ecaab346 FEAT_B: Cart Balancer (Assessment)_3121 - Correlation: 1.0
# 229: FEAT_A: a0faea5d FEAT_B: Bubble Bath_4070 - Correlation: 1.0
# 230: FEAT_A: e7561dd2 FEAT_B: Pan Balance_4025 - Correlation: 0.9999999999999998
# 231: FEAT_A: 363c86c9 FEAT_B: Bug Measurer (Activity)_4035 - Correlation: 0.9999999999999998
# 232: FEAT_A: 3ccd3f02 FEAT_B: 3dcdda7f - Correlation: 0.9977337946782776
# 233: FEAT_A: 3ccd3f02 FEAT_B: Chest Sorter (Assessment)_3110 - Correlation: 1.0
# 234: FEAT_A: 3ccd3f02 FEAT_B: Chest Sorter (Assessment)_3010 - Correlation: 0.9977337946782776
# 235: FEAT_A: 9b01374f FEAT_B: Flower Waterer (Activity)_2000 - Correlation: 1.0
# 236: FEAT_A: cc5087a3 FEAT_B: 48349b14 - Correlation: 0.992567892111789
# 237: FEAT_A: cc5087a3 FEAT_B: Crystals Rule_2000 - Correlation: 0.992567892111789
# 238: FEAT_A: cc5087a3 FEAT_B: Crystals Rule_4010 - Correlation: 0.9999999999999998
# 239: FEAT_A: 51311d7a FEAT_B: c6971acf - Correlation: 0.993166551565093
# 240: FEAT_A: 51311d7a FEAT_B: Dino Drink_2000 - Correlation: 1.0
# 241: FEAT_A: 51311d7a FEAT_B: Dino Drink_2060 - Correlation: 0.993166551565093
# 242: FEAT_A: 19967db1 FEAT_B: Chow Time_4090 - Correlation: 0.9999999999999998
# 243: FEAT_A: 1325467d FEAT_B: Sandcastle Builder (Activity)_4070 - Correlation: 1.0
# 244: FEAT_A: 2ec694de FEAT_B: Bug Measurer (Activity)_4080 - Correlation: 0.9999999999999998
# 245: FEAT_A: d88ca108 FEAT_B: Air Show_2070 - Correlation: 0.9999999999999998
# 246: FEAT_A: 6f445b57 FEAT_B: Chow Time_4080 - Correlation: 1.0
# 247: FEAT_A: f3cd5473 FEAT_B: Pan Balance_4070 - Correlation: 1.0
# 248: FEAT_A: fcfdffb6 FEAT_B: Flower Waterer (Activity)_4022 - Correlation: 1.0
# 249: FEAT_A: 47026d5f FEAT_B: cb6010f8 - Correlation: 0.9996901555713468
# 250: FEAT_A: 47026d5f FEAT_B: 56817e2b - Correlation: 0.9993683693704362
# 251: FEAT_A: 47026d5f FEAT_B: Chow Time_3121 - Correlation: 0.9996901555713468
# 252: FEAT_A: 47026d5f FEAT_B: Chow Time_2030 - Correlation: 0.9993683693704362
# 253: FEAT_A: 47026d5f FEAT_B: Chow Time_3021 - Correlation: 1.0
# 254: FEAT_A: 1cc7cfca FEAT_B: All Star Sorting_4030 - Correlation: 1.0
# 255: FEAT_A: 499edb7c FEAT_B: Chicken Balancer (Activity)_4020 - Correlation: 1.0
# 256: FEAT_A: 8d84fa81 FEAT_B: 99abe2bb - Correlation: 0.9910060294244556
# 257: FEAT_A: 8d84fa81 FEAT_B: Bubble Bath_2080 - Correlation: 0.9910060294244556
# 258: FEAT_A: 8d84fa81 FEAT_B: Bubble Bath_4010 - Correlation: 1.0
# 259: FEAT_A: 13f56524 FEAT_B: Mushroom Sorter (Assessment)_4080 - Correlation: 1.0
# 260: FEAT_A: db02c830 FEAT_B: 3bfd1a65 - Correlation: 0.9999982205265873
# 261: FEAT_A: db02c830 FEAT_B: Mushroom Sorter (Assessment)_2025 - Correlation: 1.0
# 262: FEAT_A: db02c830 FEAT_B: Mushroom Sorter (Assessment)_2000 - Correlation: 0.9999982205265873
# 263: FEAT_A: 923afab1 FEAT_B: 2dcad279 - Correlation: 0.9998567985670097
# 264: FEAT_A: 923afab1 FEAT_B: 30614231 - Correlation: 0.9915793638477989
# 265: FEAT_A: 923afab1 FEAT_B: Cauldron Filler (Assessment)_4020 - Correlation: 0.9915793638477989
# 266: FEAT_A: 923afab1 FEAT_B: Cauldron Filler (Assessment)_3110 - Correlation: 0.9998567985670097
# 267: FEAT_A: 923afab1 FEAT_B: Cauldron Filler (Assessment)_3010 - Correlation: 0.9999999999999999
# 268: FEAT_A: 5859dfb6 FEAT_B: 90ea0bac - Correlation: 0.9981052472610571
# 269: FEAT_A: 5859dfb6 FEAT_B: Bubble Bath_3120 - Correlation: 1.0
# 270: FEAT_A: 5859dfb6 FEAT_B: Bubble Bath_3020 - Correlation: 0.9981052472610571
# 271: FEAT_A: 7d5c30a2 FEAT_B: Dino Dive_2060 - Correlation: 1.0
# 272: FEAT_A: 47efca07 FEAT_B: Bottle Filler (Activity)_4090 - Correlation: 1.0
# 273: FEAT_A: f56e0afc FEAT_B: Bird Measurer (Assessment)_2000 - Correlation: 1.0
# 274: FEAT_A: d06f75b5 FEAT_B: 895865f3 - Correlation: 0.9991496470458575
# 275: FEAT_A: d06f75b5 FEAT_B: Bubble Bath_2035 - Correlation: 0.9999999999999998
# 276: FEAT_A: d06f75b5 FEAT_B: Bubble Bath_2030 - Correlation: 0.9991496470458575
# 277: FEAT_A: 7423acbc FEAT_B: e04fb33d - Correlation: 0.9996289974081254
# 278: FEAT_A: 7423acbc FEAT_B: Air Show_3120 - Correlation: 0.9996289974081254
# 279: FEAT_A: 7423acbc FEAT_B: Air Show_3020 - Correlation: 0.9999999999999999
# 280: FEAT_A: 29a42aea FEAT_B: Bubble Bath_4080 - Correlation: 1.0
# 281: FEAT_A: 77c76bc5 FEAT_B: Cauldron Filler (Assessment)_4090 - Correlation: 1.0
# 282: FEAT_A: 93b353f2 FEAT_B: ea296733 - Correlation: 0.9924234063231709
# 283: FEAT_A: 93b353f2 FEAT_B: df4fe8b6 - Correlation: 0.9927226231201971
# 284: FEAT_A: 93b353f2 FEAT_B: Chest Sorter (Assessment)_3120 - Correlation: 0.9927226231201971
# 285: FEAT_A: 93b353f2 FEAT_B: Chest Sorter (Assessment)_3020 - Correlation: 0.9924234063231709
# 286: FEAT_A: 93b353f2 FEAT_B: Chest Sorter (Assessment)_4100 - Correlation: 1.0
# 287: FEAT_A: 85d1b0de FEAT_B: Chicken Balancer (Activity)_4090 - Correlation: 0.9999999999999999
# 288: FEAT_A: c0415e5c FEAT_B: Dino Dive_4020 - Correlation: 1.0
# 289: FEAT_A: dcb55a27 FEAT_B: Air Show_4110 - Correlation: 1.0
# 290: FEAT_A: 3d0b9317 FEAT_B: Chest Sorter (Assessment)_4040 - Correlation: 1.0
# 291: FEAT_A: 5348fd84 FEAT_B: Cauldron Filler (Assessment)_4040 - Correlation: 1.0
# 292: FEAT_A: 461eace6 FEAT_B: Egg Dropper (Activity)_4020 - Correlation: 1.0
# 293: FEAT_A: 71fe8f75 FEAT_B: 0a08139c - Correlation: 0.9999850342981549
# 294: FEAT_A: 71fe8f75 FEAT_B: Bug Measurer (Activity)_3110 - Correlation: 1.0
# 295: FEAT_A: 71fe8f75 FEAT_B: Bug Measurer (Activity)_3010 - Correlation: 0.9999850342981549
# 296: FEAT_A: 9e34ea74 FEAT_B: Egg Dropper (Activity)_4070 - Correlation: 1.0
# 297: FEAT_A: e7e44842 FEAT_B: Watering Hole (Activity)_4090 - Correlation: 1.0
# 298: FEAT_A: 1575e76c FEAT_B: Air Show_2020 - Correlation: 0.9999999999999999
# 299: FEAT_A: ac92046e FEAT_B: d88e8f25 - Correlation: 0.999976307033209
# 300: FEAT_A: ac92046e FEAT_B: Scrub-A-Dub_3120 - Correlation: 1.0
# 301: FEAT_A: ac92046e FEAT_B: Scrub-A-Dub_3020 - Correlation: 0.999976307033209
# 302: FEAT_A: f806dc10 FEAT_B: Dino Drink_2020 - Correlation: 1.0
# 303: FEAT_A: 89aace00 FEAT_B: e5734469 - Correlation: 0.9998406115110343
# 304: FEAT_A: 89aace00 FEAT_B: Dino Drink_3120 - Correlation: 0.9999999999999998
# 305: FEAT_A: 89aace00 FEAT_B: Dino Drink_3020 - Correlation: 0.9998406115110343
# 306: FEAT_A: 47f43a44 FEAT_B: Flower Waterer (Activity)_4090 - Correlation: 0.9999999999999999
# 307: FEAT_A: 6f4bd64e FEAT_B: Air Show_4090 - Correlation: 1.0
# 308: FEAT_A: a8efe47b FEAT_B: Chest Sorter (Assessment)_4030 - Correlation: 1.0
# 309: FEAT_A: 3d63345e FEAT_B: Cart Balancer (Assessment)_4035 - Correlation: 0.9999999999999999
# 310: FEAT_A: bdf49a58 FEAT_B: 1375ccb7 - Correlation: 0.9993801763820361
# 311: FEAT_A: bdf49a58 FEAT_B: Bird Measurer (Assessment)_3110 - Correlation: 1.0
# 312: FEAT_A: bdf49a58 FEAT_B: Bird Measurer (Assessment)_3010 - Correlation: 0.9993801763820361
# 313: FEAT_A: 37ee8496 FEAT_B: Cauldron Filler (Assessment) - Correlation: 0.9909478215356198
# 314: FEAT_A: 37ee8496 FEAT_B: Cauldron Filler (Assessment)_4030 - Correlation: 1.0
# 315: FEAT_A: 4a4c3d21 FEAT_B: Bird Measurer (Assessment)_4025 - Correlation: 1.0
# 316: FEAT_A: 9ce586dd FEAT_B: Chest Sorter (Assessment)_4035 - Correlation: 1.0
# 317: FEAT_A: 06372577 FEAT_B: Air Show_2060 - Correlation: 1.0
# 318: FEAT_A: de26c3a6 FEAT_B: Flower Waterer (Activity)_4020 - Correlation: 1.0
# 319: FEAT_A: a7640a16 FEAT_B: Happy Camel_4070 - Correlation: 0.9999999999999999
# 320: FEAT_A: 1cf54632 FEAT_B: Bubble Bath_2000 - Correlation: 0.9999999999999999
# 321: FEAT_A: 832735e1 FEAT_B: ab3136ba - Correlation: 0.999863794577024
# 322: FEAT_A: 832735e1 FEAT_B: Dino Dive_3010 - Correlation: 0.9999999999999998
# 323: FEAT_A: 832735e1 FEAT_B: Dino Dive_3110 - Correlation: 0.999863794577024
# 324: FEAT_A: f32856e4 FEAT_B: Leaf Leader_2020 - Correlation: 1.0
# 325: FEAT_A: 3b2048ee FEAT_B: Leaf Leader_4095 - Correlation: 1.0
# 326: FEAT_A: 99ea62f3 FEAT_B: Bubble Bath_2083 - Correlation: 1.0
# 327: FEAT_A: 7525289a FEAT_B: 45d01abe - Correlation: 0.9981555049446877
# 328: FEAT_A: 7525289a FEAT_B: Bird Measurer (Assessment)_3121 - Correlation: 1.0
# 329: FEAT_A: 7525289a FEAT_B: Bird Measurer (Assessment)_3021 - Correlation: 0.9981555049446877
# 330: FEAT_A: 7fd1ac25 FEAT_B: Egg Dropper (Activity)_4080 - Correlation: 1.0
# 331: FEAT_A: 9ed8f6da FEAT_B: Dino Drink_2075 - Correlation: 0.9999999999999999
# 332: FEAT_A: beb0a7b9 FEAT_B: b88f38da - Correlation: 0.9999125179829763
# 333: FEAT_A: beb0a7b9 FEAT_B: Fireworks (Activity)_3010 - Correlation: 1.0
# 334: FEAT_A: beb0a7b9 FEAT_B: Fireworks (Activity)_3110 - Correlation: 0.9999125179829763
# 335: FEAT_A: a1bbe385 FEAT_B: f28c589a - Correlation: 0.9999536797342256
# 336: FEAT_A: a1bbe385 FEAT_B: Air Show_3010 - Correlation: 0.9999536797342256
# 337: FEAT_A: a1bbe385 FEAT_B: Air Show_3110 - Correlation: 1.0
# 338: FEAT_A: a52b92d5 FEAT_B: a1e4395d - Correlation: 0.9991003891313356
# 339: FEAT_A: a52b92d5 FEAT_B: Mushroom Sorter (Assessment)_3110 - Correlation: 1.0
# 340: FEAT_A: a52b92d5 FEAT_B: Mushroom Sorter (Assessment)_3010 - Correlation: 0.9991003891313356
# 341: FEAT_A: bd701df8 FEAT_B: 49ed92e9 - Correlation: 0.9993109138888525
# 342: FEAT_A: bd701df8 FEAT_B: Watering Hole (Activity)_3010 - Correlation: 0.9993109138888525
# 343: FEAT_A: bd701df8 FEAT_B: Watering Hole (Activity)_3110 - Correlation: 1.0
# 344: FEAT_A: a8a78786 FEAT_B: Happy Camel_3121 - Correlation: 1.0
# 345: FEAT_A: bc8f2793 FEAT_B: Pan Balance_4035 - Correlation: 1.0
# 346: FEAT_A: 05ad839b FEAT_B: Happy Camel_4090 - Correlation: 0.9999999999999999
# 347: FEAT_A: 55115cbd FEAT_B: 6f4adc4b - Correlation: 0.9997831892615403
# 348: FEAT_A: 55115cbd FEAT_B: Bubble Bath_3021 - Correlation: 0.9997831892615403
# 349: FEAT_A: 55115cbd FEAT_B: Bubble Bath_3121 - Correlation: 1.0
# 350: FEAT_A: 565a3990 FEAT_B: Bug Measurer (Activity)_4070 - Correlation: 1.0
# 351: FEAT_A: 3ee399c3 FEAT_B: Cauldron Filler (Assessment)_4070 - Correlation: 1.0
# 352: FEAT_A: 31973d56 FEAT_B: 5de79a6a - Correlation: 0.9973945339840685
# 353: FEAT_A: 31973d56 FEAT_B: Cart Balancer (Assessment)_3120 - Correlation: 1.0
# 354: FEAT_A: 31973d56 FEAT_B: Cart Balancer (Assessment)_3020 - Correlation: 0.9973945339840685
# 355: FEAT_A: 5e3ea25a FEAT_B: Crystals Rule_4070 - Correlation: 1.0
# 356: FEAT_A: 3a4be871 FEAT_B: Flower Waterer (Activity)_4080 - Correlation: 1.0
# 357: FEAT_A: 3edf6747 FEAT_B: Cauldron Filler (Assessment)_4035 - Correlation: 1.0
# 358: FEAT_A: 56cd3b43 FEAT_B: bbfe0445 - Correlation: 0.999692621535553
# 359: FEAT_A: 56cd3b43 FEAT_B: Flower Waterer (Activity)_3010 - Correlation: 0.9999999999999999
# 360: FEAT_A: 56cd3b43 FEAT_B: Flower Waterer (Activity)_3110 - Correlation: 0.999692621535553
# 361: FEAT_A: a2df0760 FEAT_B: Happy Camel_4035 - Correlation: 0.9999999999999999
# 362: FEAT_A: 7ad3efc6 FEAT_B: 65a38bf7 - Correlation: 0.999978626569042
# 363: FEAT_A: 7ad3efc6 FEAT_B: Cart Balancer (Assessment)_2000 - Correlation: 1.0
# 364: FEAT_A: 7ad3efc6 FEAT_B: Cart Balancer (Assessment)_2020 - Correlation: 0.999978626569042
# 365: FEAT_A: 76babcde FEAT_B: Dino Dive_4070 - Correlation: 0.9999999999999999
# 366: FEAT_A: b1d5101d FEAT_B: All Star Sorting_4095 - Correlation: 1.0
# 367: FEAT_A: 9e6b7fb5 FEAT_B: Chow Time_4095 - Correlation: 0.9999999999999998
# 368: FEAT_A: 598f4598 FEAT_B: Flower Waterer (Activity)_4025 - Correlation: 0.9999999999999998
# 369: FEAT_A: 67439901 FEAT_B: Bottle Filler (Activity)_3010 - Correlation: 0.9999999999999999
# 370: FEAT_A: 4bb2f698 FEAT_B: Chicken Balancer (Activity)_4070 - Correlation: 1.0
# 371: FEAT_A: 3d8c61b0 FEAT_B: Happy Camel - Correlation: 0.992634502114494
# 372: FEAT_A: 3d8c61b0 FEAT_B: Happy Camel_4030 - Correlation: 1.0
# 373: FEAT_A: 587b5989 FEAT_B: All Star Sorting_4070 - Correlation: 1.0
# 374: FEAT_A: 01ca3a3c FEAT_B: Leaf Leader_4080 - Correlation: 0.9999999999999999
# 375: FEAT_A: 87d743c1 FEAT_B: Dino Dive_4010 - Correlation: 1.0
# 376: FEAT_A: 5f0eb72c FEAT_B: fbaf3456 - Correlation: 0.9937067781355167
# 377: FEAT_A: 5f0eb72c FEAT_B: Mushroom Sorter (Assessment)_4030 - Correlation: 0.9937067781355167
# 378: FEAT_A: 5f0eb72c FEAT_B: Mushroom Sorter (Assessment)_4020 - Correlation: 1.0
# 379: FEAT_A: cb1178ad FEAT_B: Chest Sorter (Assessment)_4090 - Correlation: 1.0
# 380: FEAT_A: 16667cc5 FEAT_B: Chicken Balancer (Activity)_4080 - Correlation: 1.0
# 381: FEAT_A: 2c4e6db0 FEAT_B: All Star Sorting_2020 - Correlation: 1.0
# 382: FEAT_A: 14de4c5d FEAT_B: Air Show_4100 - Correlation: 1.0
# 383: FEAT_A: a16a373e FEAT_B: Bird Measurer (Assessment)_4070 - Correlation: 1.0
# 384: FEAT_A: 0d1da71f FEAT_B: Chow Time_3110 - Correlation: 0.9999999999999998
# 385: FEAT_A: 155f62a4 FEAT_B: 5b49460a - Correlation: 1.0
# 386: FEAT_A: 155f62a4 FEAT_B: Chest Sorter (Assessment)_2020 - Correlation: 1.0
# 387: FEAT_A: 155f62a4 FEAT_B: Chest Sorter (Assessment)_2000 - Correlation: 1.0
# 388: FEAT_A: b5053438 FEAT_B: d3268efa - Correlation: 0.9995763267046308
# 389: FEAT_A: b5053438 FEAT_B: 28520915 - Correlation: 0.9990905166101882
# 390: FEAT_A: b5053438 FEAT_B: Cauldron Filler (Assessment)_3121 - Correlation: 1.0
# 391: FEAT_A: b5053438 FEAT_B: Cauldron Filler (Assessment)_2030 - Correlation: 0.9990905166101882
# 392: FEAT_A: b5053438 FEAT_B: Cauldron Filler (Assessment)_3021 - Correlation: 0.9995763267046308
# 393: FEAT_A: 5be391b5 FEAT_B: Dino Drink_4010 - Correlation: 1.0
# 394: FEAT_A: 28f975ea FEAT_B: Air Show_4020 - Correlation: 0.9999999999999999
# 395: FEAT_A: 2b058fe3 FEAT_B: Cauldron Filler (Assessment)_2010 - Correlation: 1.0
# 396: FEAT_A: 77ead60d FEAT_B: 16dffff1 - Correlation: 0.9984674845132676
# 397: FEAT_A: 77ead60d FEAT_B: 4d911100 - Correlation: 0.9998475927724755
# 398: FEAT_A: 77ead60d FEAT_B: Dino Drink_3121 - Correlation: 0.9998475927724755
# 399: FEAT_A: 77ead60d FEAT_B: Dino Drink_3021 - Correlation: 1.0
# 400: FEAT_A: 77ead60d FEAT_B: Dino Drink_2030 - Correlation: 0.9984674845132676
# 401: FEAT_A: 7ec0c298 FEAT_B: Chow Time_3010 - Correlation: 1.0
# 402: FEAT_A: 5e109ec3 FEAT_B: Cart Balancer (Assessment)_4030 - Correlation: 0.9999999999999999
# 403: FEAT_A: 7da34a02 FEAT_B: Mushroom Sorter (Assessment)_4070 - Correlation: 0.9999999999999998
# 404: FEAT_A: 884228c8 FEAT_B: Fireworks (Activity)_4070 - Correlation: 1.0
# 405: FEAT_A: ec138c1c FEAT_B: Bird Measurer (Assessment)_2020 - Correlation: 1.0
# 406: FEAT_A: 9b23e8ee FEAT_B: 736f9581 - Correlation: 1.0
# 407: FEAT_A: 9b23e8ee FEAT_B: Egg Dropper (Activity)_2000 - Correlation: 1.0
# 408: FEAT_A: 9b23e8ee FEAT_B: Egg Dropper (Activity)_2020 - Correlation: 1.0
# 409: FEAT_A: 15ba1109 FEAT_B: Air Show_2000 - Correlation: 1.0
# 410: FEAT_A: bcceccc6 FEAT_B: Air Show_4070 - Correlation: 1.0
# 411: FEAT_A: acf5c23f FEAT_B: Cart Balancer (Assessment)_4070 - Correlation: 1.0
# 412: FEAT_A: d3f1e122 FEAT_B: Bottle Filler (Activity)_4035 - Correlation: 1.0
# 413: FEAT_A: 2dc29e21 FEAT_B: All Star Sorting_4020 - Correlation: 1.0
# 414: FEAT_A: 6bf9e3e1 FEAT_B: Happy Camel_4040 - Correlation: 0.9999999999999999
# 415: FEAT_A: 46cd75b4 FEAT_B: Chicken Balancer (Activity)_4022 - Correlation: 1.0
# 416: FEAT_A: 562cec5f FEAT_B: Chest Sorter (Assessment)_4025 - Correlation: 1.0
# 417: FEAT_A: ad2fc29c FEAT_B: Bird Measurer (Assessment)_3020 - Correlation: 1.0
# 418: FEAT_A: 63f13dd7 FEAT_B: Chow Time_2020 - Correlation: 1.0
# 419: FEAT_A: 9c5ef70c FEAT_B: Pan Balance_2000 - Correlation: 1.0
# 420: FEAT_A: 763fc34e FEAT_B: e57dd7af - Correlation: 0.9972721980394431
# 421: FEAT_A: 763fc34e FEAT_B: Leaf Leader_3120 - Correlation: 0.9972721980394431
# 422: FEAT_A: 763fc34e FEAT_B: Leaf Leader_3020 - Correlation: 1.0
# 423: FEAT_A: a29c5338 FEAT_B: 7f0836bf - Correlation: 0.9986531654717631
# 424: FEAT_A: a29c5338 FEAT_B: Dino Drink_3010 - Correlation: 1.0
# 425: FEAT_A: a29c5338 FEAT_B: Dino Drink_3110 - Correlation: 0.9986531654717631
# 426: FEAT_A: 731c0cbe FEAT_B: Bird Measurer (Assessment)_4090 - Correlation: 1.0
# 427: FEAT_A: 5c2f29ca FEAT_B: Cart Balancer (Assessment)_4020 - Correlation: 1.0
# 428: FEAT_A: 262136f4 FEAT_B: Leaf Leader_4020 - Correlation: 1.0
# 429: FEAT_A: cf82af56 FEAT_B: Scrub-A-Dub_4070 - Correlation: 1.0
# 430: FEAT_A: 4c2ec19f FEAT_B: Egg Dropper (Activity)_4025 - Correlation: 1.0
# 431: FEAT_A: 29bdd9ba FEAT_B: Dino Dive_2000 - Correlation: 1.0
# 432: FEAT_A: a8876db3 FEAT_B: Cart Balancer (Assessment)_3021 - Correlation: 1.0
# 433: FEAT_A: fd20ea40 FEAT_B: Leaf Leader_4010 - Correlation: 0.9999999999999998
# 434: FEAT_A: f54238ee FEAT_B: Fireworks (Activity)_4090 - Correlation: 0.9999999999999998
# 435: FEAT_A: 29f54413 FEAT_B: Leaf Leader_2060 - Correlation: 1.0
# 436: FEAT_A: d2278a3b FEAT_B: Bottle Filler (Activity)_2000 - Correlation: 1.0
# 437: FEAT_A: 8ac7cce4 FEAT_B: Leaf Leader_2000 - Correlation: 1.0
# 438: FEAT_A: f50fc6c1 FEAT_B: Watering Hole (Activity)_4021 - Correlation: 1.0
# 439: FEAT_A: 4d6737eb FEAT_B: Dino Drink_2070 - Correlation: 0.9999999999999998
# 440: FEAT_A: 756e5507 FEAT_B: Chicken Balancer (Activity)_2000 - Correlation: 1.0
# 441: FEAT_A: 532a2afb FEAT_B: Cauldron Filler (Assessment)_2020 - Correlation: 1.0
# 442: FEAT_A: 4a09ace1 FEAT_B: Scrub-A-Dub_2083 - Correlation: 1.0
# 443: FEAT_A: 86ba578b FEAT_B: Leaf Leader_2070 - Correlation: 1.0
# 444: FEAT_A: 6f8106d9 FEAT_B: Dino Drink_4090 - Correlation: 1.0
# 445: FEAT_A: 56bcd38d FEAT_B: Chicken Balancer (Activity) - Correlation: 0.9905582108959008
# 446: FEAT_A: 56bcd38d FEAT_B: Chicken Balancer (Activity)_4030 - Correlation: 1.0
# 447: FEAT_A: 93edfe2e FEAT_B: Crystals Rule_4090 - Correlation: 1.0
# 448: FEAT_A: eb2c19cd FEAT_B: Mushroom Sorter (Assessment)_4090 - Correlation: 1.0
# 449: FEAT_A: b7dc8128 FEAT_B: 4b5efe37 - Correlation: 0.9980151285383978
# 450: FEAT_A: b7dc8128 FEAT_B: All Star Sorting_4010 - Correlation: 0.9980151285383978
# 451: FEAT_A: b7dc8128 FEAT_B: All Star Sorting_2000 - Correlation: 0.9999999999999999
# 452: FEAT_A: 5f5b2617 FEAT_B: Bottle Filler (Activity)_4080 - Correlation: 0.9999999999999999
# 453: FEAT_A: 828e68f9 FEAT_B: 795e4a37 - Correlation: 0.9937646978910051
# 454: FEAT_A: 828e68f9 FEAT_B: Cart Balancer (Assessment)_3110 - Correlation: 1.0
# 455: FEAT_A: 828e68f9 FEAT_B: Cart Balancer (Assessment)_3010 - Correlation: 0.9937646978910051
# 456: FEAT_A: c952eb01 FEAT_B: Watering Hole (Activity)_4070 - Correlation: 0.9999999999999998
# 457: FEAT_A: c7128948 FEAT_B: Mushroom Sorter (Assessment)_4040 - Correlation: 1.0
# 458: FEAT_A: f6947f54 FEAT_B: Bird Measurer (Assessment)_2030 - Correlation: 0.9999999999999999
# 459: FEAT_A: 6077cc36 FEAT_B: Bird Measurer (Assessment)_4080 - Correlation: 1.0
# 460: FEAT_A: 9e4c8c7b FEAT_B: 363d3849 - Correlation: 0.9992130941883628
# 461: FEAT_A: 9e4c8c7b FEAT_B: All Star Sorting_3110 - Correlation: 0.9999999999999998
# 462: FEAT_A: 9e4c8c7b FEAT_B: All Star Sorting_3010 - Correlation: 0.9992130941883628
# 463: FEAT_A: 3bb91ced FEAT_B: Happy Camel_2081 - Correlation: 1.0
# 464: FEAT_A: 2fb91ec1 FEAT_B: d2e9262e - Correlation: 0.9991434495208746
# 465: FEAT_A: 2fb91ec1 FEAT_B: Watering Hole (Activity)_4025 - Correlation: 0.9999999999999998
# 466: FEAT_A: 2fb91ec1 FEAT_B: Watering Hole (Activity)_4020 - Correlation: 0.9991434495208746
# 467: FEAT_A: e64e2cfd FEAT_B: Watering Hole (Activity)_2000 - Correlation: 1.0
# 468: FEAT_A: 92687c59 FEAT_B: Scrub-A-Dub_4090 - Correlation: 1.0
# 469: FEAT_A: c1cac9a2 FEAT_B: Scrub-A-Dub_2081 - Correlation: 1.0
# 470: FEAT_A: 30df3273 FEAT_B: Sandcastle Builder (Activity)_4080 - Correlation: 0.9999999999999999
# 471: FEAT_A: 119b5b02 FEAT_B: Dino Dive_4080 - Correlation: 0.9999999999999998
# 472: FEAT_A: a5be6304 FEAT_B: 6c930e6e - Correlation: 0.9962760616821659
# 473: FEAT_A: a5be6304 FEAT_B: Mushroom Sorter (Assessment)_2030 - Correlation: 0.9962760616821659
# 474: FEAT_A: a5be6304 FEAT_B: Mushroom Sorter (Assessment)_2010 - Correlation: 1.0
# 475: FEAT_A: 84538528 FEAT_B: Sandcastle Builder (Activity)_4020 - Correlation: 1.0
# 476: FEAT_A: 6c517a88 FEAT_B: Dino Drink_4070 - Correlation: 1.0
# 477: FEAT_A: e694a35b FEAT_B: Fireworks (Activity)_4020 - Correlation: 1.0
# 478: FEAT_A: d02b7a8e FEAT_B: All Star Sorting_4035 - Correlation: 1.0
# 479: FEAT_A: 6d90d394 FEAT_B: Scrub-A-Dub_2000 - Correlation: 1.0
# 480: FEAT_A: 0ce40006 FEAT_B: Happy Camel_4080 - Correlation: 0.9999999999999999
# 481: FEAT_A: d185d3ea FEAT_B: Chow Time_4035 - Correlation: 1.0
# 482: FEAT_A: 7040c096 FEAT_B: Scrub-A-Dub_4010 - Correlation: 1.0
# 483: FEAT_A: ab4ec3a4 FEAT_B: Dino Drink_4080 - Correlation: 0.9999999999999999
# 484: FEAT_A: a44b10dc FEAT_B: Flower Waterer (Activity)_4070 - Correlation: 1.0
# 485: FEAT_A: 4e5fc6f5 FEAT_B: Cart Balancer (Assessment)_4090 - Correlation: 0.9999999999999999
# 486: FEAT_A: 8af75982 FEAT_B: Happy Camel_4020 - Correlation: 1.0
# 487: FEAT_A: 53c6e11a FEAT_B: Leaf Leader_2075 - Correlation: 1.0
# 488: FEAT_A: 00c73085 FEAT_B: Dino Dive_2030 - Correlation: 1.0
# 489: FEAT_A: d2659ab4 FEAT_B: Air Show_2075 - Correlation: 1.0
# 490: FEAT_A: 77261ab5 FEAT_B: Sandcastle Builder (Activity)_2000 - Correlation: 0.9999999999999999
# 491: FEAT_A: 7dfe6d8a FEAT_B: Leaf Leader_4070 - Correlation: 0.9999999999999998
# 492: FEAT_A: e4d32835 FEAT_B: Pan Balance_4080 - Correlation: 1.0
# 493: FEAT_A: bfc77bd6 FEAT_B: Chest Sorter (Assessment)_4080 - Correlation: 0.9999999999999998
# 494: FEAT_A: 792530f8 FEAT_B: Dino Drink - Correlation: 0.9905195065432535
# 495: FEAT_A: 792530f8 FEAT_B: Dino Drink_4030 - Correlation: 1.0
# 496: FEAT_A: 611485c5 FEAT_B: Fireworks (Activity)_4080 - Correlation: 1.0
# 497: FEAT_A: 1b54d27f FEAT_B: Watering Hole (Activity)_2010 - Correlation: 1.0
# 498: FEAT_A: a5e9da97 FEAT_B: Pan Balance_4100 - Correlation: 1.0
# 499: FEAT_A: ecc36b7f FEAT_B: Bubble Bath_4095 - Correlation: 0.9999999999999998
# 500: FEAT_A: d9c005dd FEAT_B: Happy Camel_2000 - Correlation: 1.0
# 501: FEAT_A: 8d748b58 FEAT_B: Bug Measurer (Activity)_4090 - Correlation: 0.9999999999999998
# 502: FEAT_A: 0d18d96c FEAT_B: Mushroom Sorter (Assessment)_4035 - Correlation: 1.0
# 503: FEAT_A: 6043a2b4 FEAT_B: All Star Sorting_4090 - Correlation: 1.0
# 504: FEAT_A: 5c3d2b2f FEAT_B: Scrub-A-Dub - Correlation: 0.9911772362413135
# 505: FEAT_A: 5c3d2b2f FEAT_B: Scrub-A-Dub_4020 - Correlation: 1.0
# 506: FEAT_A: cdd22e43 FEAT_B: Chicken Balancer (Activity)_4035 - Correlation: 1.0
# 507: FEAT_A: 6aeafed4 FEAT_B: Bubble Bath_4090 - Correlation: 0.9999999999999998
# 508: FEAT_A: c7f7f0e1 FEAT_B: Bug Measurer (Activity)_2000 - Correlation: 1.0
# 509: FEAT_A: Heavy, Heavier, Heaviest FEAT_B: Heavy, Heavier, Heaviest_2000 - Correlation: 0.9999999999999998
# 510: FEAT_A: Lifting Heavy Things FEAT_B: Lifting Heavy Things_2000 - Correlation: 1.0
# 511: FEAT_A: Balancing Act FEAT_B: Balancing Act_2000 - Correlation: 1.0
# 512: FEAT_A: Pirate's Tale FEAT_B: Pirate's Tale_2000 - Correlation: 1.0
# 513: FEAT_A: 12 Monkeys FEAT_B: 12 Monkeys_2000 - Correlation: 1.0
# 514: FEAT_A: Treasure Map FEAT_B: Treasure Map_2000 - Correlation: 1.0
# 515: FEAT_A: Tree Top City - Level 1 FEAT_B: Tree Top City - Level 1_2000 - Correlation: 1.0
# 516: FEAT_A: Crystal Caves - Level 2 FEAT_B: Crystal Caves - Level 2_2000 - Correlation: 0.9999999999999998
# 517: FEAT_A: Rulers FEAT_B: Rulers_2000 - Correlation: 1.0
# 518: FEAT_A: Tree Top City - Level 2 FEAT_B: Tree Top City - Level 2_2000 - Correlation: 1.0
# 519: FEAT_A: Magma Peak - Level 2 FEAT_B: Magma Peak - Level 2_2000 - Correlation: 1.0
# 520: FEAT_A: Magma Peak - Level 1 FEAT_B: Magma Peak - Level 1_2000 - Correlation: 1.0
# 521: FEAT_A: Slop Problem FEAT_B: Slop Problem_2000 - Correlation: 1.0
# 522: FEAT_A: Tree Top City - Level 3 FEAT_B: Tree Top City - Level 3_2000 - Correlation: 0.9999999999999998
# 523: FEAT_A: Welcome to Lost Lagoon! FEAT_B: Welcome to Lost Lagoon!_2000 - Correlation: 1.0
# 524: FEAT_A: Honey Cake FEAT_B: Honey Cake_2000 - Correlation: 1.0
# 525: FEAT_A: Crystal Caves - Level 1 FEAT_B: Crystal Caves - Level 1_2000 - Correlation: 1.0
# 526: FEAT_A: Costume Box FEAT_B: Costume Box_2000 - Correlation: 1.0
# 527: FEAT_A: Crystal Caves - Level 3 FEAT_B: Crystal Caves - Level 3_2000 - Correlation: 0.9999999999999998
# 528: FEAT_A: Ordering Spheres FEAT_B: Ordering Spheres_2000 - Correlation: 0.9999999999999998
# 529: FEAT_A: var_event_id FEAT_B: var_title_event_code - Correlation: 0.9995254184300612
# 530: FEAT_A: accumulated_accuracy FEAT_B: accumulated_accuracy_group - Correlation: 0.9948505839879956

# %%
to_exclude = [] 
ajusted_test = reduce_test.copy()
for feature in ajusted_test.columns:
    if feature not in ['accuracy_group', 'installation_id', 'accuracy_group', 'session_title']:
        data = reduce_train[feature]
        train_mean = data.mean()
        data = ajusted_test[feature] 
        test_mean = data.mean()
        try:
            error = stract_hists(feature, adjust=True)
            ajust_factor = train_mean / test_mean
            if ajust_factor > 10 or ajust_factor < 0.1:# or error > 0.01:
                to_exclude.append(feature)
                print(feature, train_mean, test_mean, error)
            else:
                ajusted_test[feature] *= ajust_factor
        except:
            to_exclude.append(feature)
            print(feature, train_mean, test_mean)
# Out:
# acc_Cart Balancer (Assessment) -0.04020325710970116 -0.47065833333333346 0.006732930476733109
# 003cd2ee 0.0 0.0
# ecc6157f 0.007292255511588468 0.0
# 2ec694de 0.008988128886376484 0.0
# 4074bac2 0.0 0.0
# a8cc6fec 0.0 0.0
# 13f56524 0.04392312040700961 0.0
# 17ca3959 0.0 0.0
# 29a42aea 0.004070096099491238 0.0
# dcb1663e 0.0 0.0
# 7fd1ac25 0.01978518937252685 0.0
# 01ca3a3c 0.0004522328999434709 0.0
# eb2c19cd 0.17382702091577162 0.008 0.0
# 119b5b02 0.0002826455624646693 0.0
# 5dc079d8 0.0 0.0
# 0ce40006 0.0008479366873940079 0.0
# ab4ec3a4 0.0009044657998869418 0.0
# e4d32835 0.0013001695873374789 0.0
# bfc77bd6 0.012832108535895986 0.0
# 611485c5 0.0013566986998304127 0.0
# 1b54d27f 0.0007348784624081402 0.0
# 6aeafed4 0.14703222159412097 0.008 0.0
# Mushroom Sorter (Assessment)_4080 0.04392312040700961 0.0
# Dino Dive_4080 0.0002826455624646693 0.0
# Fireworks (Activity)_4080 0.0013566986998304127 0.0
# Scrub-A-Dub_4080 0.0 0.0
# Pan Balance_2010 0.0 0.0
# Crystals Rule_2010 0.0 0.0
# Sandcastle Builder (Activity)_2010 0.0 0.0
# Chest Sorter (Assessment)_4080 0.012832108535895986 0.0
# Happy Camel_4080 0.0008479366873940079 0.0
# Egg Dropper (Activity)_4080 0.01978518937252685 0.0
# Leaf Leader_4080 0.0004522328999434709 0.0
# Cart Balancer (Assessment)_4080 0.007292255511588468 0.0
# Bug Measurer (Activity)_4080 0.008988128886376484 0.0
# Bottle Filler (Activity)_2010 0.0 0.0
# Watering Hole (Activity)_2010 0.0007348784624081402 0.0
# Bubble Bath_4090 0.14703222159412097 0.008 0.0
# Air Show_4080 0.0 0.0
# Mushroom Sorter (Assessment)_4090 0.17382702091577162 0.008 0.0
# Pan Balance_4080 0.0013001695873374789 0.0
# Dino Drink_4080 0.0009044657998869418 0.0
# Bubble Bath_4080 0.004070096099491238 0.0

# %%
features = [x for x in features if x not in (to_exclude + to_remove)]
reduce_train[features].shape
# Out:
# (17690, 341)

# %%
#cat_model = Catb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
lgb_model = Lgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
xgb_model = Xgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# Out:
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1243: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.03368	valid_1's rmse: 1.05174
# [200]	training's rmse: 0.967007	valid_1's rmse: 1.00339
# [300]	training's rmse: 0.933516	valid_1's rmse: 0.987055
# [400]	training's rmse: 0.909978	valid_1's rmse: 0.980209
# [500]	training's rmse: 0.891104	valid_1's rmse: 0.976979
# [600]	training's rmse: 0.874536	valid_1's rmse: 0.975294
# [700]	training's rmse: 0.859656	valid_1's rmse: 0.974726
# [800]	training's rmse: 0.845961	valid_1's rmse: 0.974573
# [900]	training's rmse: 0.832981	valid_1's rmse: 0.974407
# Early stopping, best iteration is:
# [852]	training's rmse: 0.839198	valid_1's rmse: 0.974285
# Partial score of fold 0 is: 0.6013899825327051
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.03135	valid_1's rmse: 1.05113
# [200]	training's rmse: 0.964154	valid_1's rmse: 1.00662
# [300]	training's rmse: 0.930012	valid_1's rmse: 0.993509
# [400]	training's rmse: 0.906211	valid_1's rmse: 0.989183
# [500]	training's rmse: 0.887291	valid_1's rmse: 0.987813
# [600]	training's rmse: 0.871139	valid_1's rmse: 0.987677
# Early stopping, best iteration is:
# [559]	training's rmse: 0.877586	valid_1's rmse: 0.987526
# Partial score of fold 1 is: 0.5875561161516147
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.03162	valid_1's rmse: 1.05345
# [200]	training's rmse: 0.96467	valid_1's rmse: 1.00737
# [300]	training's rmse: 0.931235	valid_1's rmse: 0.993493
# [400]	training's rmse: 0.908063	valid_1's rmse: 0.987616
# [500]	training's rmse: 0.889283	valid_1's rmse: 0.985034
# [600]	training's rmse: 0.872821	valid_1's rmse: 0.983752
# [700]	training's rmse: 0.858083	valid_1's rmse: 0.983146
# [800]	training's rmse: 0.844379	valid_1's rmse: 0.982846
# [900]	training's rmse: 0.831537	valid_1's rmse: 0.982884
# Early stopping, best iteration is:
# [879]	training's rmse: 0.834037	valid_1's rmse: 0.98283
# Partial score of fold 2 is: 0.5914926738282588
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.03209	valid_1's rmse: 1.05386
# [200]	training's rmse: 0.965119	valid_1's rmse: 1.00879
# [300]	training's rmse: 0.931401	valid_1's rmse: 0.994672
# [400]	training's rmse: 0.908096	valid_1's rmse: 0.9889
# [500]	training's rmse: 0.889091	valid_1's rmse: 0.986202
# [600]	training's rmse: 0.872691	valid_1's rmse: 0.985072
# [700]	training's rmse: 0.857856	valid_1's rmse: 0.984302
# [800]	training's rmse: 0.844227	valid_1's rmse: 0.984528
# Early stopping, best iteration is:
# [724]	training's rmse: 0.854407	valid_1's rmse: 0.984153
# Partial score of fold 3 is: 0.5929241493470384
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.03136	valid_1's rmse: 1.05621
# [200]	training's rmse: 0.964919	valid_1's rmse: 1.01147
# [300]	training's rmse: 0.931734	valid_1's rmse: 0.995777
# [400]	training's rmse: 0.90828	valid_1's rmse: 0.988953
# [500]	training's rmse: 0.889445	valid_1's rmse: 0.985716
# [600]	training's rmse: 0.873306	valid_1's rmse: 0.983407
# [700]	training's rmse: 0.858451	valid_1's rmse: 0.98242
# [800]	training's rmse: 0.844937	valid_1's rmse: 0.981641
# [900]	training's rmse: 0.832149	valid_1's rmse: 0.981266
# [1000]	training's rmse: 0.81987	valid_1's rmse: 0.981116
# Early stopping, best iteration is:
# [994]	training's rmse: 0.820577	valid_1's rmse: 0.981023
# Partial score of fold 4 is: 0.590690772131911
# Our oof cohen kappa score is:  0.5937427463162637
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:1.8564	val-rmse:1.85696
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.02386	val-rmse:1.15388
# [200]	train-rmse:0.753926	val-rmse:1.00994
# [300]	train-rmse:0.634885	val-rmse:0.985357
# [400]	train-rmse:0.573254	val-rmse:0.982575
# [500]	train-rmse:0.540914	val-rmse:0.982629
# Stopping. Best iteration:
# [476]	train-rmse:0.547151	val-rmse:0.982414
#
# Partial score of fold 0 is: 0.5895819658572826
# [0]	train-rmse:1.85627	val-rmse:1.85757
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.02076	val-rmse:1.17
# [200]	train-rmse:0.745317	val-rmse:1.02583
# [300]	train-rmse:0.628994	val-rmse:0.999014
# [400]	train-rmse:0.568301	val-rmse:0.994638
# [500]	train-rmse:0.531088	val-rmse:0.994535
# Stopping. Best iteration:
# [421]	train-rmse:0.559276	val-rmse:0.994342
#
# Partial score of fold 1 is: 0.5753885742419877
# [0]	train-rmse:1.85635	val-rmse:1.85724
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.02199	val-rmse:1.15445
# [200]	train-rmse:0.752348	val-rmse:1.01008
# [300]	train-rmse:0.636954	val-rmse:0.98432
# [400]	train-rmse:0.573492	val-rmse:0.981622
# [500]	train-rmse:0.537968	val-rmse:0.981951
# Stopping. Best iteration:
# [411]	train-rmse:0.568521	val-rmse:0.981501
#
# Partial score of fold 2 is: 0.5990079203018519
# [0]	train-rmse:1.85631	val-rmse:1.8574
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.02042	val-rmse:1.15724
# [200]	train-rmse:0.748802	val-rmse:1.0165
# [300]	train-rmse:0.633793	val-rmse:0.993166
# [400]	train-rmse:0.577192	val-rmse:0.989718
# [500]	train-rmse:0.54066	val-rmse:0.988821
# [600]	train-rmse:0.515153	val-rmse:0.989447
# Stopping. Best iteration:
# [526]	train-rmse:0.534097	val-rmse:0.988705
#
# Partial score of fold 3 is: 0.5900611983094791
# [0]	train-rmse:1.85628	val-rmse:1.85762
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.02515	val-rmse:1.15901
# [200]	train-rmse:0.754411	val-rmse:1.01778
# [300]	train-rmse:0.639089	val-rmse:0.994585
# [400]	train-rmse:0.575087	val-rmse:0.990603
# [500]	train-rmse:0.535071	val-rmse:0.990425
# Stopping. Best iteration:
# [441]	train-rmse:0.555825	val-rmse:0.99018
#
# Partial score of fold 4 is: 0.5756538269576623
# Our oof cohen kappa score is:  0.5859404309869487

# %%
#cnn_model = Cnn_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
nn_model = Nn_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:100: DeprecationWarning: The ``active_features_`` attribute was deprecated in version 0.20 and will be removed 0.22.
#   warnings.warn(msg, category=DeprecationWarning)
# (17690, 346)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               69400
# _________________________________________________________________
# layer_normalization (LayerNo (None, 200)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 100)               200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 50)                100
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 25)                1275
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 25)                50
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 96,601
# Trainable params: 96,601
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14151 samples, validate on 3539 samples
# Epoch 1/100
# 14048/14151 [============================>.] - ETA: 0s - loss: 1.9535
# Epoch 00001: val_loss improved from inf to 1.11607, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 231us/sample - loss: 1.9485 - val_loss: 1.1161
# Epoch 2/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 1.4104
# Epoch 00002: val_loss improved from 1.11607 to 1.07902, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 161us/sample - loss: 1.4090 - val_loss: 1.0790
# Epoch 3/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 1.2958
# Epoch 00003: val_loss improved from 1.07902 to 1.06821, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 158us/sample - loss: 1.2972 - val_loss: 1.0682
# Epoch 4/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 1.2302
# Epoch 00004: val_loss improved from 1.06821 to 1.05615, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 161us/sample - loss: 1.2258 - val_loss: 1.0562
# Epoch 5/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 1.1925
# Epoch 00005: val_loss improved from 1.05615 to 1.04779, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 163us/sample - loss: 1.1924 - val_loss: 1.0478
# Epoch 6/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 1.1764
# Epoch 00006: val_loss improved from 1.04779 to 1.03793, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 162us/sample - loss: 1.1765 - val_loss: 1.0379
# Epoch 7/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 1.1497
# Epoch 00007: val_loss improved from 1.03793 to 1.02810, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 160us/sample - loss: 1.1494 - val_loss: 1.0281
# Epoch 8/100
# 13824/14151 [============================>.] - ETA: 0s - loss: 1.1247
# Epoch 00008: val_loss did not improve from 1.02810
# 14151/14151 [==============================] - 2s 159us/sample - loss: 1.1241 - val_loss: 1.0489
# Epoch 9/100
# 13792/14151 [============================>.] - ETA: 0s - loss: 1.1188
# Epoch 00009: val_loss improved from 1.02810 to 1.01944, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 159us/sample - loss: 1.1186 - val_loss: 1.0194
# Epoch 10/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 1.1044
# Epoch 00010: val_loss improved from 1.01944 to 1.00392, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 163us/sample - loss: 1.1028 - val_loss: 1.0039
# Epoch 11/100
# 13824/14151 [============================>.] - ETA: 0s - loss: 1.0936
# Epoch 00011: val_loss did not improve from 1.00392
# 14151/14151 [==============================] - 2s 160us/sample - loss: 1.0937 - val_loss: 1.0404
# Epoch 12/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 1.0778
# Epoch 00012: val_loss improved from 1.00392 to 1.00308, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 160us/sample - loss: 1.0786 - val_loss: 1.0031
# Epoch 13/100
# 14144/14151 [============================>.] - ETA: 0s - loss: 1.0685
# Epoch 00013: val_loss improved from 1.00308 to 0.99595, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 162us/sample - loss: 1.0685 - val_loss: 0.9960
# Epoch 14/100
# 14048/14151 [============================>.] - ETA: 0s - loss: 1.0640
# Epoch 00014: val_loss improved from 0.99595 to 0.98528, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 163us/sample - loss: 1.0631 - val_loss: 0.9853
# Epoch 15/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 1.0507
# Epoch 00015: val_loss did not improve from 0.98528
# 14151/14151 [==============================] - 2s 161us/sample - loss: 1.0515 - val_loss: 0.9902
# Epoch 16/100
# 14048/14151 [============================>.] - ETA: 0s - loss: 1.0466
# Epoch 00016: val_loss did not improve from 0.98528
# 14151/14151 [==============================] - 2s 158us/sample - loss: 1.0455 - val_loss: 0.9991
# Epoch 17/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 1.0282
# Epoch 00017: val_loss did not improve from 0.98528
# 14151/14151 [==============================] - 2s 159us/sample - loss: 1.0279 - val_loss: 0.9859
# Epoch 18/100
# 14080/14151 [============================>.] - ETA: 0s - loss: 1.0246
# Epoch 00018: val_loss improved from 0.98528 to 0.98076, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 160us/sample - loss: 1.0237 - val_loss: 0.9808
# Epoch 19/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 1.0152
# Epoch 00019: val_loss did not improve from 0.98076
# 14151/14151 [==============================] - 2s 164us/sample - loss: 1.0149 - val_loss: 0.9830
# Epoch 20/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 1.0091
# Epoch 00020: val_loss improved from 0.98076 to 0.97552, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 163us/sample - loss: 1.0099 - val_loss: 0.9755
# Epoch 21/100
# 14080/14151 [============================>.] - ETA: 0s - loss: 0.9979
# Epoch 00021: val_loss did not improve from 0.97552
# 14151/14151 [==============================] - 2s 165us/sample - loss: 0.9972 - val_loss: 0.9803
# Epoch 22/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.9976
# Epoch 00022: val_loss did not improve from 0.97552
# 14151/14151 [==============================] - 2s 164us/sample - loss: 0.9975 - val_loss: 0.9877
# Epoch 23/100
# 14080/14151 [============================>.] - ETA: 0s - loss: 0.9748
# Epoch 00023: val_loss did not improve from 0.97552
# 14151/14151 [==============================] - 2s 161us/sample - loss: 0.9756 - val_loss: 0.9997
# Epoch 24/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 0.9772
# Epoch 00024: val_loss did not improve from 0.97552
# 14151/14151 [==============================] - 2s 159us/sample - loss: 0.9762 - val_loss: 0.9890
# Epoch 25/100
# 13856/14151 [============================>.] - ETA: 0s - loss: 0.9734
# Epoch 00025: val_loss did not improve from 0.97552
# 14151/14151 [==============================] - 2s 156us/sample - loss: 0.9706 - val_loss: 0.9888
# Epoch 26/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 0.9654
# Epoch 00026: val_loss did not improve from 0.97552
# 14151/14151 [==============================] - 2s 156us/sample - loss: 0.9607 - val_loss: 0.9764
# Epoch 27/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 0.9652
# Epoch 00027: val_loss did not improve from 0.97552
# 14151/14151 [==============================] - 2s 163us/sample - loss: 0.9624 - val_loss: 0.9786
# Epoch 28/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.9381
# Epoch 00028: val_loss improved from 0.97552 to 0.96584, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 163us/sample - loss: 0.9384 - val_loss: 0.9658
# Epoch 29/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.9383
# Epoch 00029: val_loss did not improve from 0.96584
# 14151/14151 [==============================] - 2s 159us/sample - loss: 0.9368 - val_loss: 0.9733
# Epoch 30/100
# 14080/14151 [============================>.] - ETA: 0s - loss: 0.9397
# Epoch 00030: val_loss did not improve from 0.96584
# 14151/14151 [==============================] - 2s 166us/sample - loss: 0.9397 - val_loss: 0.9869
# Epoch 31/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 0.9178
# Epoch 00031: val_loss improved from 0.96584 to 0.96376, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 204us/sample - loss: 0.9169 - val_loss: 0.9638
# Epoch 32/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 0.9260
# Epoch 00032: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 160us/sample - loss: 0.9264 - val_loss: 0.9799
# Epoch 33/100
# 14080/14151 [============================>.] - ETA: 0s - loss: 0.9103
# Epoch 00033: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 156us/sample - loss: 0.9107 - val_loss: 0.9809
# Epoch 34/100
# 14080/14151 [============================>.] - ETA: 0s - loss: 0.8997
# Epoch 00034: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 158us/sample - loss: 0.8993 - val_loss: 0.9865
# Epoch 35/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 0.8936
# Epoch 00035: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 157us/sample - loss: 0.8938 - val_loss: 0.9837
# Epoch 36/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.8956
# Epoch 00036: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 159us/sample - loss: 0.8957 - val_loss: 0.9701
# Epoch 37/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.8932
# Epoch 00037: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 158us/sample - loss: 0.8928 - val_loss: 0.9757
# Epoch 38/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 0.8835
# Epoch 00038: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 159us/sample - loss: 0.8847 - val_loss: 0.9738
# Epoch 39/100
# 13792/14151 [============================>.] - ETA: 0s - loss: 0.8740
# Epoch 00039: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 159us/sample - loss: 0.8717 - val_loss: 0.9944
# Epoch 40/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.8801
# Epoch 00040: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 161us/sample - loss: 0.8801 - val_loss: 0.9849
# Epoch 41/100
# 14048/14151 [============================>.] - ETA: 0s - loss: 0.8643
# Epoch 00041: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 160us/sample - loss: 0.8630 - val_loss: 0.9903
# Epoch 42/100
# 14144/14151 [============================>.] - ETA: 0s - loss: 0.8595
# Epoch 00042: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 158us/sample - loss: 0.8597 - val_loss: 0.9899
# Epoch 43/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 0.8498
# Epoch 00043: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 159us/sample - loss: 0.8490 - val_loss: 1.0032
# Epoch 44/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 0.8497
# Epoch 00044: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 160us/sample - loss: 0.8494 - val_loss: 1.0184
# Epoch 45/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 0.8434
# Epoch 00045: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 163us/sample - loss: 0.8413 - val_loss: 1.0163
# Epoch 46/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 0.8361
# Epoch 00046: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 158us/sample - loss: 0.8372 - val_loss: 1.0166
# Epoch 47/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.8368
# Epoch 00047: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 159us/sample - loss: 0.8378 - val_loss: 1.0030
# Epoch 48/100
# 14048/14151 [============================>.] - ETA: 0s - loss: 0.8368
# Epoch 00048: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 162us/sample - loss: 0.8372 - val_loss: 1.0020
# Epoch 49/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.8253
# Epoch 00049: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 161us/sample - loss: 0.8255 - val_loss: 1.0004
# Epoch 50/100
# 13824/14151 [============================>.] - ETA: 0s - loss: 0.8104
# Epoch 00050: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 159us/sample - loss: 0.8087 - val_loss: 1.0109
# Epoch 51/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 0.8110
# Epoch 00051: val_loss did not improve from 0.96376
# 14151/14151 [==============================] - 2s 159us/sample - loss: 0.8099 - val_loss: 0.9839
# Partial score of fold 0 is: 0.6006743451584371
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 200)               69400
# _________________________________________________________________
# layer_normalization_4 (Layer (None, 200)               400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               20100
# _________________________________________________________________
# layer_normalization_5 (Layer (None, 100)               200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                5050
# _________________________________________________________________
# layer_normalization_6 (Layer (None, 50)                100
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 25)                1275
# _________________________________________________________________
# layer_normalization_7 (Layer (None, 25)                50
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 96,601
# Trainable params: 96,601
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14152 samples, validate on 3538 samples
# Epoch 1/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 2.0834
# Epoch 00001: val_loss improved from inf to 1.15853, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 206us/sample - loss: 2.0754 - val_loss: 1.1585
# Epoch 2/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 1.4641
# Epoch 00002: val_loss improved from 1.15853 to 1.09425, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.4649 - val_loss: 1.0943
# Epoch 3/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.3293
# Epoch 00003: val_loss improved from 1.09425 to 1.06472, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 156us/sample - loss: 1.3288 - val_loss: 1.0647
# Epoch 4/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.2573
# Epoch 00004: val_loss improved from 1.06472 to 1.04437, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.2576 - val_loss: 1.0444
# Epoch 5/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 1.2247
# Epoch 00005: val_loss improved from 1.04437 to 1.03266, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 159us/sample - loss: 1.2249 - val_loss: 1.0327
# Epoch 6/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 1.1801
# Epoch 00006: val_loss improved from 1.03266 to 1.02968, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 159us/sample - loss: 1.1806 - val_loss: 1.0297
# Epoch 7/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.1617
# Epoch 00007: val_loss improved from 1.02968 to 1.02836, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 159us/sample - loss: 1.1604 - val_loss: 1.0284
# Epoch 8/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.1386
# Epoch 00008: val_loss did not improve from 1.02836
# 14152/14152 [==============================] - 2s 155us/sample - loss: 1.1393 - val_loss: 1.0447
# Epoch 9/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 1.1200
# Epoch 00009: val_loss improved from 1.02836 to 1.02210, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 159us/sample - loss: 1.1204 - val_loss: 1.0221
# Epoch 10/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.0974
# Epoch 00010: val_loss improved from 1.02210 to 1.01325, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 165us/sample - loss: 1.1009 - val_loss: 1.0132
# Epoch 11/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.0869
# Epoch 00011: val_loss did not improve from 1.01325
# 14152/14152 [==============================] - 2s 158us/sample - loss: 1.0883 - val_loss: 1.0153
# Epoch 12/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.0913
# Epoch 00012: val_loss improved from 1.01325 to 1.00823, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.0901 - val_loss: 1.0082
# Epoch 13/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.0626
# Epoch 00013: val_loss did not improve from 1.00823
# 14152/14152 [==============================] - 2s 158us/sample - loss: 1.0627 - val_loss: 1.0119
# Epoch 14/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 1.0509
# Epoch 00014: val_loss did not improve from 1.00823
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.0514 - val_loss: 1.0117
# Epoch 15/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 1.0383
# Epoch 00015: val_loss did not improve from 1.00823
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.0384 - val_loss: 1.0092
# Epoch 16/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.0274
# Epoch 00016: val_loss improved from 1.00823 to 0.99805, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 159us/sample - loss: 1.0274 - val_loss: 0.9980
# Epoch 17/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 1.0212
# Epoch 00017: val_loss improved from 0.99805 to 0.99506, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 159us/sample - loss: 1.0218 - val_loss: 0.9951
# Epoch 18/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.0097
# Epoch 00018: val_loss did not improve from 0.99506
# 14152/14152 [==============================] - 3s 181us/sample - loss: 1.0094 - val_loss: 1.0006
# Epoch 19/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.9997
# Epoch 00019: val_loss improved from 0.99506 to 0.99298, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 185us/sample - loss: 1.0014 - val_loss: 0.9930
# Epoch 20/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9873
# Epoch 00020: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 164us/sample - loss: 0.9885 - val_loss: 0.9996
# Epoch 21/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 0.9957
# Epoch 00021: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 158us/sample - loss: 0.9958 - val_loss: 1.0015
# Epoch 22/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 0.9703
# Epoch 00022: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 157us/sample - loss: 0.9711 - val_loss: 1.0136
# Epoch 23/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 0.9556
# Epoch 00023: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 158us/sample - loss: 0.9551 - val_loss: 1.0046
# Epoch 24/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 0.9574
# Epoch 00024: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 155us/sample - loss: 0.9543 - val_loss: 0.9972
# Epoch 25/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.9458
# Epoch 00025: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 154us/sample - loss: 0.9448 - val_loss: 0.9946
# Epoch 26/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 0.9349
# Epoch 00026: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 154us/sample - loss: 0.9372 - val_loss: 1.0142
# Epoch 27/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.9248
# Epoch 00027: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 158us/sample - loss: 0.9252 - val_loss: 1.0232
# Epoch 28/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 0.9198
# Epoch 00028: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 160us/sample - loss: 0.9195 - val_loss: 1.0062
# Epoch 29/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 0.9201
# Epoch 00029: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 157us/sample - loss: 0.9189 - val_loss: 1.0080
# Epoch 30/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.9098
# Epoch 00030: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 157us/sample - loss: 0.9103 - val_loss: 1.0086
# Epoch 31/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.8949
# Epoch 00031: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 158us/sample - loss: 0.8953 - val_loss: 1.0189
# Epoch 32/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 0.8912
# Epoch 00032: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 161us/sample - loss: 0.8919 - val_loss: 0.9982
# Epoch 33/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 0.8844
# Epoch 00033: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 159us/sample - loss: 0.8838 - val_loss: 1.0253
# Epoch 34/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.8794
# Epoch 00034: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 159us/sample - loss: 0.8807 - val_loss: 1.0257
# Epoch 35/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.8711
# Epoch 00035: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 157us/sample - loss: 0.8703 - val_loss: 1.0327
# Epoch 36/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.8720
# Epoch 00036: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 159us/sample - loss: 0.8685 - val_loss: 1.0551
# Epoch 37/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.8588
# Epoch 00037: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 157us/sample - loss: 0.8582 - val_loss: 1.0179
# Epoch 38/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.8638
# Epoch 00038: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 157us/sample - loss: 0.8637 - val_loss: 1.0156
# Epoch 39/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.8533
# Epoch 00039: val_loss did not improve from 0.99298
# 14152/14152 [==============================] - 2s 155us/sample - loss: 0.8536 - val_loss: 1.0280
# Partial score of fold 1 is: 0.5837984929148182
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 200)               69400
# _________________________________________________________________
# layer_normalization_8 (Layer (None, 200)               400
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 100)               20100
# _________________________________________________________________
# layer_normalization_9 (Layer (None, 100)               200
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 50)                5050
# _________________________________________________________________
# layer_normalization_10 (Laye (None, 50)                100
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 25)                1275
# _________________________________________________________________
# layer_normalization_11 (Laye (None, 25)                50
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 96,601
# Trainable params: 96,601
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14152 samples, validate on 3538 samples
# Epoch 1/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 2.0155
# Epoch 00001: val_loss improved from inf to 1.17389, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 208us/sample - loss: 2.0144 - val_loss: 1.1739
# Epoch 2/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 1.4133
# Epoch 00002: val_loss improved from 1.17389 to 1.11992, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 162us/sample - loss: 1.4134 - val_loss: 1.1199
# Epoch 3/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 1.2899
# Epoch 00003: val_loss improved from 1.11992 to 1.09737, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 161us/sample - loss: 1.2863 - val_loss: 1.0974
# Epoch 4/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 1.2351
# Epoch 00004: val_loss improved from 1.09737 to 1.08529, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 162us/sample - loss: 1.2335 - val_loss: 1.0853
# Epoch 5/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 1.1904
# Epoch 00005: val_loss improved from 1.08529 to 1.07953, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 166us/sample - loss: 1.1924 - val_loss: 1.0795
# Epoch 6/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.1616
# Epoch 00006: val_loss improved from 1.07953 to 1.07143, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.1616 - val_loss: 1.0714
# Epoch 7/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.1386
# Epoch 00007: val_loss improved from 1.07143 to 1.05703, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 163us/sample - loss: 1.1382 - val_loss: 1.0570
# Epoch 8/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 1.1187
# Epoch 00008: val_loss improved from 1.05703 to 1.03824, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 165us/sample - loss: 1.1192 - val_loss: 1.0382
# Epoch 9/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.1033
# Epoch 00009: val_loss did not improve from 1.03824
# 14152/14152 [==============================] - 2s 165us/sample - loss: 1.1041 - val_loss: 1.0477
# Epoch 10/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 1.1071
# Epoch 00010: val_loss did not improve from 1.03824
# 14152/14152 [==============================] - 2s 163us/sample - loss: 1.1080 - val_loss: 1.0471
# Epoch 11/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.0827
# Epoch 00011: val_loss improved from 1.03824 to 1.03176, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 164us/sample - loss: 1.0830 - val_loss: 1.0318
# Epoch 12/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 1.0581
# Epoch 00012: val_loss did not improve from 1.03176
# 14152/14152 [==============================] - 2s 162us/sample - loss: 1.0596 - val_loss: 1.0337
# Epoch 13/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.0543
# Epoch 00013: val_loss improved from 1.03176 to 1.01684, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 166us/sample - loss: 1.0537 - val_loss: 1.0168
# Epoch 14/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 1.0480
# Epoch 00014: val_loss did not improve from 1.01684
# 14152/14152 [==============================] - 2s 165us/sample - loss: 1.0502 - val_loss: 1.0224
# Epoch 15/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.0437
# Epoch 00015: val_loss did not improve from 1.01684
# 14152/14152 [==============================] - 2s 163us/sample - loss: 1.0449 - val_loss: 1.0271
# Epoch 16/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.0197
# Epoch 00016: val_loss improved from 1.01684 to 1.01259, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 163us/sample - loss: 1.0197 - val_loss: 1.0126
# Epoch 17/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.0145
# Epoch 00017: val_loss improved from 1.01259 to 1.00741, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 163us/sample - loss: 1.0166 - val_loss: 1.0074
# Epoch 18/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.0132
# Epoch 00018: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 163us/sample - loss: 1.0110 - val_loss: 1.0484
# Epoch 19/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.0010
# Epoch 00019: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 162us/sample - loss: 1.0014 - val_loss: 1.0163
# Epoch 20/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.9862
# Epoch 00020: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 160us/sample - loss: 0.9866 - val_loss: 1.0309
# Epoch 21/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.9802
# Epoch 00021: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 160us/sample - loss: 0.9812 - val_loss: 1.0250
# Epoch 22/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.9722
# Epoch 00022: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 162us/sample - loss: 0.9743 - val_loss: 1.0159
# Epoch 23/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9720
# Epoch 00023: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 161us/sample - loss: 0.9708 - val_loss: 1.0367
# Epoch 24/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 0.9540
# Epoch 00024: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 160us/sample - loss: 0.9536 - val_loss: 1.0106
# Epoch 25/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.9465
# Epoch 00025: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 160us/sample - loss: 0.9473 - val_loss: 1.0203
# Epoch 26/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.9447
# Epoch 00026: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 162us/sample - loss: 0.9443 - val_loss: 1.0223
# Epoch 27/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.9262
# Epoch 00027: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 163us/sample - loss: 0.9253 - val_loss: 1.0156
# Epoch 28/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.9250
# Epoch 00028: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 160us/sample - loss: 0.9276 - val_loss: 1.0081
# Epoch 29/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.9317
# Epoch 00029: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 160us/sample - loss: 0.9309 - val_loss: 1.0150
# Epoch 30/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.9056
# Epoch 00030: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 161us/sample - loss: 0.9050 - val_loss: 1.0077
# Epoch 31/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 0.9032
# Epoch 00031: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 164us/sample - loss: 0.9044 - val_loss: 1.0204
# Epoch 32/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.8989
# Epoch 00032: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 160us/sample - loss: 0.8998 - val_loss: 1.0221
# Epoch 33/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 0.8803
# Epoch 00033: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 161us/sample - loss: 0.8822 - val_loss: 1.0097
# Epoch 34/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.8830
# Epoch 00034: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 161us/sample - loss: 0.8817 - val_loss: 1.0339
# Epoch 35/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.8732
# Epoch 00035: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 162us/sample - loss: 0.8733 - val_loss: 1.0316
# Epoch 36/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.8621
# Epoch 00036: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 3s 180us/sample - loss: 0.8621 - val_loss: 1.0534
# Epoch 37/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.8550
# Epoch 00037: val_loss did not improve from 1.00741
# 14152/14152 [==============================] - 2s 166us/sample - loss: 0.8552 - val_loss: 1.0150
# Partial score of fold 2 is: 0.5739570987232081
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 200)               69400
# _________________________________________________________________
# layer_normalization_12 (Laye (None, 200)               400
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 100)               20100
# _________________________________________________________________
# layer_normalization_13 (Laye (None, 100)               200
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 50)                5050
# _________________________________________________________________
# layer_normalization_14 (Laye (None, 50)                100
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 25)                1275
# _________________________________________________________________
# layer_normalization_15 (Laye (None, 25)                50
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 96,601
# Trainable params: 96,601
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14152 samples, validate on 3538 samples
# Epoch 1/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 1.8797
# Epoch 00001: val_loss improved from inf to 1.17010, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 207us/sample - loss: 1.8796 - val_loss: 1.1701
# Epoch 2/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 1.3738
# Epoch 00002: val_loss improved from 1.17010 to 1.09624, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 175us/sample - loss: 1.3721 - val_loss: 1.0962
# Epoch 3/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.2892
# Epoch 00003: val_loss improved from 1.09624 to 1.08532, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 176us/sample - loss: 1.2886 - val_loss: 1.0853
# Epoch 4/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 1.2265
# Epoch 00004: val_loss improved from 1.08532 to 1.06781, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 196us/sample - loss: 1.2288 - val_loss: 1.0678
# Epoch 5/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.1966
# Epoch 00005: val_loss improved from 1.06781 to 1.05638, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 245us/sample - loss: 1.1970 - val_loss: 1.0564
# Epoch 6/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 1.1794
# Epoch 00006: val_loss improved from 1.05638 to 1.04092, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.1795 - val_loss: 1.0409
# Epoch 7/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.1604
# Epoch 00007: val_loss improved from 1.04092 to 1.03968, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 163us/sample - loss: 1.1616 - val_loss: 1.0397
# Epoch 8/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.1298
# Epoch 00008: val_loss did not improve from 1.03968
# 14152/14152 [==============================] - 2s 159us/sample - loss: 1.1289 - val_loss: 1.0497
# Epoch 9/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.1151
# Epoch 00009: val_loss improved from 1.03968 to 1.02926, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 162us/sample - loss: 1.1149 - val_loss: 1.0293
# Epoch 10/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.0983
# Epoch 00010: val_loss did not improve from 1.02926
# 14152/14152 [==============================] - 2s 157us/sample - loss: 1.0954 - val_loss: 1.0443
# Epoch 11/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.0910
# Epoch 00011: val_loss improved from 1.02926 to 1.02781, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.0899 - val_loss: 1.0278
# Epoch 12/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.0738
# Epoch 00012: val_loss improved from 1.02781 to 1.02362, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.0762 - val_loss: 1.0236
# Epoch 13/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.0540
# Epoch 00013: val_loss did not improve from 1.02362
# 14152/14152 [==============================] - 2s 161us/sample - loss: 1.0534 - val_loss: 1.0270
# Epoch 14/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.0537
# Epoch 00014: val_loss improved from 1.02362 to 1.01990, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.0529 - val_loss: 1.0199
# Epoch 15/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 1.0434
# Epoch 00015: val_loss improved from 1.01990 to 1.01711, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.0432 - val_loss: 1.0171
# Epoch 16/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 1.0296
# Epoch 00016: val_loss did not improve from 1.01711
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.0264 - val_loss: 1.0229
# Epoch 17/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.0223
# Epoch 00017: val_loss improved from 1.01711 to 1.00997, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.0223 - val_loss: 1.0100
# Epoch 18/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.0047
# Epoch 00018: val_loss did not improve from 1.00997
# 14152/14152 [==============================] - 2s 163us/sample - loss: 1.0016 - val_loss: 1.0110
# Epoch 19/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.9955
# Epoch 00019: val_loss improved from 1.00997 to 1.00921, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 0.9959 - val_loss: 1.0092
# Epoch 20/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 1.0021
# Epoch 00020: val_loss improved from 1.00921 to 1.00856, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 164us/sample - loss: 1.0030 - val_loss: 1.0086
# Epoch 21/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.9683
# Epoch 00021: val_loss did not improve from 1.00856
# 14152/14152 [==============================] - 2s 166us/sample - loss: 0.9681 - val_loss: 1.0197
# Epoch 22/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.9781
# Epoch 00022: val_loss did not improve from 1.00856
# 14152/14152 [==============================] - 2s 165us/sample - loss: 0.9785 - val_loss: 1.0194
# Epoch 23/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.9562
# Epoch 00023: val_loss improved from 1.00856 to 1.00823, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 163us/sample - loss: 0.9572 - val_loss: 1.0082
# Epoch 24/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.9582
# Epoch 00024: val_loss improved from 1.00823 to 1.00219, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 0.9578 - val_loss: 1.0022
# Epoch 25/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.9472
# Epoch 00025: val_loss did not improve from 1.00219
# 14152/14152 [==============================] - 2s 159us/sample - loss: 0.9469 - val_loss: 1.0055
# Epoch 26/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 0.9418
# Epoch 00026: val_loss did not improve from 1.00219
# 14152/14152 [==============================] - 2s 161us/sample - loss: 0.9416 - val_loss: 1.0232
# Epoch 27/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9289
# Epoch 00027: val_loss did not improve from 1.00219
# 14152/14152 [==============================] - 2s 160us/sample - loss: 0.9293 - val_loss: 1.0149
# Epoch 28/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.9197
# Epoch 00028: val_loss did not improve from 1.00219
# 14152/14152 [==============================] - 2s 155us/sample - loss: 0.9204 - val_loss: 1.0329
# Epoch 29/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.9227
# Epoch 00029: val_loss did not improve from 1.00219
# 14152/14152 [==============================] - 2s 158us/sample - loss: 0.9240 - val_loss: 1.0123
# Epoch 30/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.9128
# Epoch 00030: val_loss did not improve from 1.00219
# 14152/14152 [==============================] - 2s 158us/sample - loss: 0.9114 - val_loss: 1.0196
# Epoch 31/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 0.9159
# Epoch 00031: val_loss did not improve from 1.00219
# 14152/14152 [==============================] - 2s 161us/sample - loss: 0.9138 - val_loss: 1.0121
# Epoch 32/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 0.9025
# Epoch 00032: val_loss did not improve from 1.00219
# ...
# Epoch 41/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.8494
# Epoch 00041: val_loss did not improve from 1.00219
# 14152/14152 [==============================] - 2s 157us/sample - loss: 0.8492 - val_loss: 1.0469
# Epoch 42/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.8343
# Epoch 00042: val_loss did not improve from 1.00219
# 14152/14152 [==============================] - 2s 156us/sample - loss: 0.8321 - val_loss: 1.0339
# Epoch 43/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 0.8343
# Epoch 00043: val_loss did not improve from 1.00219
# 14152/14152 [==============================] - 2s 159us/sample - loss: 0.8343 - val_loss: 1.0255
# Epoch 44/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 0.8251
# Epoch 00044: val_loss did not improve from 1.00219
# 14152/14152 [==============================] - 2s 161us/sample - loss: 0.8261 - val_loss: 1.0301
# Partial score of fold 3 is: 0.5821880829561912
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 200)               69400
# _________________________________________________________________
# layer_normalization_16 (Laye (None, 200)               400
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 100)               20100
# _________________________________________________________________
# layer_normalization_17 (Laye (None, 100)               200
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 50)                5050
# _________________________________________________________________
# layer_normalization_18 (Laye (None, 50)                100
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 25)                1275
# _________________________________________________________________
# layer_normalization_19 (Laye (None, 25)                50
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 96,601
# Trainable params: 96,601
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14153 samples, validate on 3537 samples
# Epoch 1/100
# 14016/14153 [============================>.] - ETA: 0s - loss: 2.1636
# Epoch 00001: val_loss improved from inf to 1.19977, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 204us/sample - loss: 2.1553 - val_loss: 1.1998
# Epoch 2/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 1.4964
# Epoch 00002: val_loss improved from 1.19977 to 1.11631, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 163us/sample - loss: 1.4950 - val_loss: 1.1163
# Epoch 3/100
# 14144/14153 [============================>.] - ETA: 0s - loss: 1.3214
# Epoch 00003: val_loss improved from 1.11631 to 1.08031, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 166us/sample - loss: 1.3208 - val_loss: 1.0803
# Epoch 4/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 1.2640
# Epoch 00004: val_loss improved from 1.08031 to 1.07197, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 163us/sample - loss: 1.2636 - val_loss: 1.0720
# Epoch 5/100
# 14016/14153 [============================>.] - ETA: 0s - loss: 1.2162
# Epoch 00005: val_loss improved from 1.07197 to 1.06147, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 163us/sample - loss: 1.2161 - val_loss: 1.0615
# Epoch 6/100
# 13824/14153 [============================>.] - ETA: 0s - loss: 1.1851
# Epoch 00006: val_loss improved from 1.06147 to 1.05816, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 163us/sample - loss: 1.1855 - val_loss: 1.0582
# Epoch 7/100
# 13824/14153 [============================>.] - ETA: 0s - loss: 1.1631
# Epoch 00007: val_loss improved from 1.05816 to 1.05532, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 168us/sample - loss: 1.1624 - val_loss: 1.0553
# Epoch 8/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 1.1445
# Epoch 00008: val_loss improved from 1.05532 to 1.03672, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 166us/sample - loss: 1.1445 - val_loss: 1.0367
# Epoch 9/100
# 13984/14153 [============================>.] - ETA: 0s - loss: 1.1218
# Epoch 00009: val_loss did not improve from 1.03672
# 14153/14153 [==============================] - 2s 162us/sample - loss: 1.1215 - val_loss: 1.0370
# Epoch 10/100
# 14016/14153 [============================>.] - ETA: 0s - loss: 1.1061
# Epoch 00010: val_loss improved from 1.03672 to 1.03317, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 164us/sample - loss: 1.1070 - val_loss: 1.0332
# Epoch 11/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 1.0968
# Epoch 00011: val_loss did not improve from 1.03317
# 14153/14153 [==============================] - 2s 162us/sample - loss: 1.0990 - val_loss: 1.0435
# Epoch 12/100
# 14016/14153 [============================>.] - ETA: 0s - loss: 1.0862
# Epoch 00012: val_loss improved from 1.03317 to 1.03065, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 167us/sample - loss: 1.0851 - val_loss: 1.0307
# Epoch 13/100
# 13984/14153 [============================>.] - ETA: 0s - loss: 1.0598
# Epoch 00013: val_loss improved from 1.03065 to 1.01959, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 163us/sample - loss: 1.0637 - val_loss: 1.0196
# Epoch 14/100
# 13984/14153 [============================>.] - ETA: 0s - loss: 1.0572
# Epoch 00014: val_loss did not improve from 1.01959
# 14153/14153 [==============================] - 2s 168us/sample - loss: 1.0572 - val_loss: 1.0205
# Epoch 15/100
# 13824/14153 [============================>.] - ETA: 0s - loss: 1.0572
# Epoch 00015: val_loss did not improve from 1.01959
# 14153/14153 [==============================] - 2s 165us/sample - loss: 1.0581 - val_loss: 1.0213
# Epoch 16/100
# 14016/14153 [============================>.] - ETA: 0s - loss: 1.0344
# Epoch 00016: val_loss did not improve from 1.01959
# 14153/14153 [==============================] - 2s 167us/sample - loss: 1.0352 - val_loss: 1.0289
# Epoch 17/100
# 13824/14153 [============================>.] - ETA: 0s - loss: 1.0241
# Epoch 00017: val_loss improved from 1.01959 to 1.00620, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 165us/sample - loss: 1.0225 - val_loss: 1.0062
# Epoch 18/100
# 13920/14153 [============================>.] - ETA: 0s - loss: 1.0085
# Epoch 00018: val_loss did not improve from 1.00620
# 14153/14153 [==============================] - 2s 163us/sample - loss: 1.0093 - val_loss: 1.0238
# Epoch 19/100
# 13920/14153 [============================>.] - ETA: 0s - loss: 1.0047
# Epoch 00019: val_loss did not improve from 1.00620
# 14153/14153 [==============================] - 2s 163us/sample - loss: 1.0067 - val_loss: 1.0164
# Epoch 20/100
# 13984/14153 [============================>.] - ETA: 0s - loss: 0.9863
# Epoch 00020: val_loss did not improve from 1.00620
# 14153/14153 [==============================] - 2s 166us/sample - loss: 0.9891 - val_loss: 1.0072
# Epoch 21/100
# 13952/14153 [============================>.] - ETA: 0s - loss: 0.9885
# Epoch 00021: val_loss did not improve from 1.00620
# 14153/14153 [==============================] - 2s 162us/sample - loss: 0.9878 - val_loss: 1.0127
# Epoch 22/100
# 13984/14153 [============================>.] - ETA: 0s - loss: 0.9756
# Epoch 00022: val_loss did not improve from 1.00620
# 14153/14153 [==============================] - 2s 162us/sample - loss: 0.9761 - val_loss: 1.0272
# Epoch 23/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 0.9523
# Epoch 00023: val_loss did not improve from 1.00620
# 14153/14153 [==============================] - 2s 165us/sample - loss: 0.9522 - val_loss: 1.0134
# Epoch 24/100
# 14016/14153 [============================>.] - ETA: 0s - loss: 0.9577
# Epoch 00024: val_loss improved from 1.00620 to 1.00382, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 167us/sample - loss: 0.9568 - val_loss: 1.0038
# Epoch 25/100
# 14144/14153 [============================>.] - ETA: 0s - loss: 0.9396
# Epoch 00025: val_loss improved from 1.00382 to 1.00055, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 166us/sample - loss: 0.9395 - val_loss: 1.0005
# Epoch 26/100
# 13952/14153 [============================>.] - ETA: 0s - loss: 0.9401
# Epoch 00026: val_loss did not improve from 1.00055
# 14153/14153 [==============================] - 2s 167us/sample - loss: 0.9372 - val_loss: 1.0065
# Epoch 27/100
# 13952/14153 [============================>.] - ETA: 0s - loss: 0.9358
# Epoch 00027: val_loss did not improve from 1.00055
# 14153/14153 [==============================] - 3s 183us/sample - loss: 0.9351 - val_loss: 1.0301
# Epoch 28/100
# 13920/14153 [============================>.] - ETA: 0s - loss: 0.9270
# Epoch 00028: val_loss did not improve from 1.00055
# 14153/14153 [==============================] - 3s 184us/sample - loss: 0.9286 - val_loss: 1.0270
# Epoch 29/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 0.9082
# Epoch 00029: val_loss did not improve from 1.00055
# 14153/14153 [==============================] - 2s 162us/sample - loss: 0.9077 - val_loss: 1.0049
# Epoch 30/100
# 13824/14153 [============================>.] - ETA: 0s - loss: 0.9105
# Epoch 00030: val_loss did not improve from 1.00055
# 14153/14153 [==============================] - 2s 157us/sample - loss: 0.9099 - val_loss: 1.0226
# Epoch 31/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 0.8995
# Epoch 00031: val_loss did not improve from 1.00055
# 14153/14153 [==============================] - 2s 160us/sample - loss: 0.8995 - val_loss: 1.0084
# Epoch 32/100
# 14144/14153 [============================>.] - ETA: 0s - loss: 0.8885
# Epoch 00032: val_loss did not improve from 1.00055
# 14153/14153 [==============================] - 2s 161us/sample - loss: 0.8889 - val_loss: 1.0042
# Epoch 33/100
# 14080/14153 [============================>.] - ETA: 0s - loss: 0.8787
# Epoch 00033: val_loss improved from 1.00055 to 0.99519, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 167us/sample - loss: 0.8780 - val_loss: 0.9952
# Epoch 34/100
# 13920/14153 [============================>.] - ETA: 0s - loss: 0.8812
# Epoch 00034: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 164us/sample - loss: 0.8802 - val_loss: 1.0221
# Epoch 35/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 0.8685
# Epoch 00035: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 161us/sample - loss: 0.8689 - val_loss: 1.0139
# Epoch 36/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 0.8643
# Epoch 00036: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 165us/sample - loss: 0.8639 - val_loss: 1.0274
# Epoch 37/100
# 14016/14153 [============================>.] - ETA: 0s - loss: 0.8578
# Epoch 00037: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 165us/sample - loss: 0.8588 - val_loss: 1.0208
# Epoch 38/100
# 13792/14153 [============================>.] - ETA: 0s - loss: 0.8519
# Epoch 00038: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 160us/sample - loss: 0.8500 - val_loss: 1.0491
# Epoch 39/100
# 13984/14153 [============================>.] - ETA: 0s - loss: 0.8483
# Epoch 00039: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 163us/sample - loss: 0.8490 - val_loss: 1.0237
# Epoch 40/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 0.8391
# Epoch 00040: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 162us/sample - loss: 0.8392 - val_loss: 1.0405
# Epoch 41/100
# 13888/14153 [============================>.] - ETA: 0s - loss: 0.8350
# Epoch 00041: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 163us/sample - loss: 0.8345 - val_loss: 1.0552
# Epoch 42/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.8334
# Epoch 00042: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 163us/sample - loss: 0.8342 - val_loss: 1.0248
# Epoch 43/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.8144
# Epoch 00043: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 161us/sample - loss: 0.8148 - val_loss: 1.0309
# Epoch 44/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.8046
# Epoch 00044: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 160us/sample - loss: 0.8034 - val_loss: 1.0415
# Epoch 45/100
# 13888/14153 [============================>.] - ETA: 0s - loss: 0.8165
# Epoch 00045: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 159us/sample - loss: 0.8174 - val_loss: 1.0265
# Epoch 46/100
# 13920/14153 [============================>.] - ETA: 0s - loss: 0.7951
# Epoch 00046: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 163us/sample - loss: 0.7951 - val_loss: 1.0121
# Epoch 47/100
# 13824/14153 [============================>.] - ETA: 0s - loss: 0.7948
# Epoch 00047: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 162us/sample - loss: 0.7930 - val_loss: 1.0323
# Epoch 48/100
# 13984/14153 [============================>.] - ETA: 0s - loss: 0.7948
# Epoch 00048: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 159us/sample - loss: 0.7950 - val_loss: 1.0296
# Epoch 49/100
# 14144/14153 [============================>.] - ETA: 0s - loss: 0.7892
# Epoch 00049: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 161us/sample - loss: 0.7891 - val_loss: 1.0307
# Epoch 50/100
# 14048/14153 [============================>.] - ETA: 0s - loss: 0.7892
# Epoch 00050: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 163us/sample - loss: 0.7879 - val_loss: 1.0253
# Epoch 51/100
# 13952/14153 [============================>.] - ETA: 0s - loss: 0.7958
# Epoch 00051: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 159us/sample - loss: 0.7941 - val_loss: 1.0434
# Epoch 52/100
# 13952/14153 [============================>.] - ETA: 0s - loss: 0.7792
# Epoch 00052: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 160us/sample - loss: 0.7770 - val_loss: 1.0514
# Epoch 53/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.7830
# Epoch 00053: val_loss did not improve from 0.99519
# 14153/14153 [==============================] - 2s 161us/sample - loss: 0.7841 - val_loss: 1.0571
# Partial score of fold 4 is: 0.5797710857553733
# Our oof cohen kappa score is:  0.5848309274309452

# %%
weights = {'lbg': 0.50, 'cat': 0, 'xgb': 0.25, 'nn': 0.25}

final_pred = (lgb_model.y_pred * weights['lbg']) + (xgb_model.y_pred * weights['xgb']) + (nn_model.y_pred * weights['nn'])
#final_pred = cnn_model.y_pred
print(final_pred.shape)
# Out:
# (1000,)

# %%
#pd.DataFrame([(round(a, 2), round(b, 2), round(c, 2), round(d, 2)) for a, b, c, d in zip(lgb_model.y_pred, cat_model.y_pred, xgb_model.y_pred, nn_model.y_pred)], columns=['lgb', 'cat', 'xgb', 'nn']).head(50)

# %%
dist = Counter(reduce_train['accuracy_group'])
for k in dist:
    dist[k] /= len(reduce_train)
reduce_train['accuracy_group'].hist()

acum = 0
bound = {}
for i in range(3):
    acum += dist[i]
    bound[i] = np.percentile(final_pred, acum * 100)
print(bound)

def classify(x):
    if x <= bound[0]:
        return 0
    elif x <= bound[1]:
        return 1
    elif x <= bound[2]:
        return 2
    else:
        return 3
    
final_pred = np.array(list(map(classify, final_pred)))

sample_submission['accuracy_group'] = final_pred.astype(int)
sample_submission.to_csv('submission.csv', index=False)
sample_submission['accuracy_group'].value_counts(normalize=True)
# Out:
# {0: 1.2549322572701058, 1: 1.7075491702854717, 2: 1.9425911952294026}
# 3    0.500
# 0    0.239
# 1    0.136
# 2    0.125
# Name: accuracy_group, dtype: float64
