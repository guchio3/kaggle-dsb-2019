# %%
import os
import sys
import json
from tqdm import tqdm_notebook as tqdm
from pprint import pprint

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
from matplotlib_venn import venn2
import seaborn as sns

# %%
pd.set_option('max_rows', 200)
pd.set_option('max_columns', 200)

# %% [markdown]
# ## data load

# %%
BASE_DIR = '../mnt/inputs/origin'
TRN_BASE_DIR = '../mnt/inputs/features/train'
TST_BASE_DIR = '../mnt/inputs/features/test'
# BASE_DIR = '../mnt/inputs/features/test'

# %%
# !ls $BASE_DIR
# !ls $TRN_BASE_DIR
# Out:
# data-science-bowl-2019.zip  test.csv	  train2.csv
# sample_submission.csv	    train.csv	  train_labels.csv
# specs.csv		    train.pkl.gz
# specs_w_event_id.csv	    train1.csv
# EncodingTitles.pkl  PrevAssessAcc.pkl	      befTargetCntFeatures.pkl
# EventCount.pkl	    PrevAssessAccByTitle.pkl  immediatelyBeforeFeatures.pkl
# EventCount2.pkl     PrevAssessResult.pkl      worldGameNumeriacalFeatures.pkl
# GameDurMiss.pkl     SessionTime2.pkl
# KernelBasics3.pkl   Worldcount.pkl

# %%
trn_df = pd.read_pickle(f'{BASE_DIR}/train.pkl.gz')
specs_df = pd.read_csv(f'{BASE_DIR}/specs_w_event_id.csv')
display(trn_df.shape, trn_df.head())
# Out:
# (11341042, 11)
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count  event_code  game_time                          title  \
# 0            1        2000          0        Welcome to Lost Lagoon!
# 1            1        2000          0           Magma Peak - Level 1
# 2            1        2000          0  Sandcastle Builder (Activity)
# 3            2        3010         53  Sandcastle Builder (Activity)
# 4            3        3110       6972  Sandcastle Builder (Activity)
#
#        type      world
# 0      Clip       NONE
# 1      Clip  MAGMAPEAK
# 2  Activity  MAGMAPEAK
# 3  Activity  MAGMAPEAK
# 4  Activity  MAGMAPEAK

# %%
trn_labels_df = pd.read_csv(f'{BASE_DIR}/train_labels.csv')
display(trn_labels_df.shape, trn_labels_df.head())
# Out:
# (17690, 7)
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1  77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2  901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3  9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4  a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0            1              0       1.0               3
# 1            0             11       0.0               0
# 2            1              0       1.0               3
# 3            1              1       0.5               2
# 4            1              0       1.0               3

# %%
tst_df = pd.read_csv(f'{BASE_DIR}/test.csv')
tst_df.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  0ea9ecc81a565215  2019-09-10T16:50:24.910Z
# 1  27253bdc  c1ea43d8b8261d27  2019-09-10T16:50:55.503Z
# 2  27253bdc  7ed86c6b72e725e2  2019-09-10T16:51:51.805Z
# 3  27253bdc  7e516ace50e7fe67  2019-09-10T16:53:12.825Z
# 4  7d093bf9  a022c3f60ba547e7  2019-09-10T16:54:12.115Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        00abaee7
# 1             {"event_code": 2000, "event_count": 1}        00abaee7
# 2             {"event_code": 2000, "event_count": 1}        00abaee7
# 3             {"event_code": 2000, "event_count": 1}        00abaee7
# 4  {"version":"1.0","round":0,"event_count":1,"ga...        00abaee7
#
#    event_count  event_code  game_time                    title  type  \
# 0            1        2000          0  Welcome to Lost Lagoon!  Clip
# 1            1        2000          0     Magma Peak - Level 1  Clip
# 2            1        2000          0     Magma Peak - Level 2  Clip
# 3            1        2000          0  Crystal Caves - Level 1  Clip
# 4            1        2000          0                Chow Time  Game
#
#           world
# 0          NONE
# 1     MAGMAPEAK
# 2     MAGMAPEAK
# 3  CRYSTALCAVES
# 4  CRYSTALCAVES

# %%
sub_df = pd.read_csv(f'{BASE_DIR}/sample_submission.csv')
sub_df.head()
# Out:
#   installation_id  accuracy_group
# 0        00abaee7               3
# 1        01242218               3
# 2        017c5718               3
# 3        01a44906               3
# 4        01bc6cb6               3

# %% [markdown]
# ## oof 見てみる

# %%
import pickle

with open('../mnt/oofs/e026/e026_oof.pkl', 'rb') as fin:
    oof = pickle.load(fin)
with open('../mnt/oofs/e026/e026_prediction.pkl', 'rb') as fin:
    prediction = pickle.load(fin)

# %%
oof.shape
# Out:
# (17690,)

# %%
trn_labels_df['y_preds'] = oof

# %%
trn_labels_df[['accuracy_group', 'y_preds']].corr('spearman')
# Out:
#                 accuracy_group   y_preds
# accuracy_group        1.000000  0.008847
# y_preds               0.008847  1.000000

# %%
trn_labels_df[['accuracy_group', 'y_preds']].corr('spearman')
# Out:
#                 accuracy_group   y_preds
# accuracy_group        1.000000  0.265434
# y_preds               0.265434  1.000000

# %%
import scipy as sp
from functools import partial

class OptimizedRounder(object):
    """
    An optimizer for rounding thresholds
    to maximize Quadratic Weighted Kappa (QWK) score
    # https://www.kaggle.com/naveenasaithambi/optimizedrounder-improved
    """

    def __init__(self):
        self.coef_ = 0

    def _kappa_loss(self, coef, X, y):
        """
        Get loss according to
        using current coefficients
        :param coef: A list of coefficients that will be used for rounding
        :param X: The raw predictions
        :param y: The ground truth labels
        """
        X_p = pd.cut(X, [-np.inf] + list(np.sort(coef)) +
                     [np.inf], labels=[0, 1, 2, 3])

        return -qwk(y, X_p)

    def fit(self, X, y, initial_coef=[1.0, 1.5, 2.0]):
        """
        Optimize rounding thresholds
        :param X: The raw predictions
        :param y: The ground truth labels
        """
        loss_partial = partial(self._kappa_loss, X=X, y=y)
        self.coef_ = sp.optimize.minimize(
            loss_partial, initial_coef, method='nelder-mead')

    def predict(self, X, coef):
        """
        Make predictions with specified thresholds
        :param X: The raw predictions
        :param coef: A list of coefficients that will be used for rounding
        """
        return pd.cut(X, [-np.inf] + list(np.sort(coef)) +
                      [np.inf], labels=[0, 1, 2, 3])

    def coefficients(self):
        """
        Return the optimized coefficients
        """
        return self.coef_['x']

def qwk(y_true, y_pred, max_rat=3):
    y_true_ = np.asarray(y_true, dtype=int)
    y_pred_ = np.asarray(y_pred, dtype=int)

    hist1 = np.zeros((max_rat + 1, ))
    hist2 = np.zeros((max_rat + 1, ))

    numerator = 0
    for k in range(y_true_.shape[0]):
        i, j = y_true_[k], y_pred_[k]
        hist1[i] += 1
        hist2[j] += 1
        numerator += (i - j) * (i - j)

    denominator = 0
    for i in range(max_rat + 1):
        for j in range(max_rat + 1):
            denominator += hist1[i] * hist2[j] * (i - j) * (i - j)

    denominator /= y_true_.shape[0]
    return 1 - numerator / denominator

from collections import Counter
from sklearn.metrics import cohen_kappa_score
def eval_qwk_lgb_regr(y_true, y_pred):
    """
    Fast cappa eval function for lgb.
    """
    dist = Counter(y_true)
    for k in dist:
        dist[k] /= len(y_true)
    pd.Series(y_true).hist()
    
    acum = 0
    bound = {}
    for i in range(3):
        acum += dist[i]
        bound[i] = np.percentile(y_pred, acum * 100)

    def classify(x):
        if x <= bound[0]:
            return 0
        elif x <= bound[1]:
            return 1
        elif x <= bound[2]:
            return 2
        else:
            return 3

    y_pred = np.array(list(map(classify, y_pred))).reshape(y_true.shape)

    return 'cappa', cohen_kappa_score(y_true, y_pred, weights='quadratic'), True

# %%
kb_df = pd.read_pickle('../mnt/inputs/features/train/KernelBasics3.pkl')

# %%
optR = OptimizedRounder()
optR.fit(oof[oof != 0], kb_df['accuracy_group'][oof != 0])
coefficients = optR.coefficients()

opt_preds = optR.predict(oof[oof != 0], coefficients)

# %%
opt_prediction = optR.predict(prediction, coefficients)

plt.hist(opt_prediction)
plt.show()

plt.hist(opt_preds)
plt.show()

# %%
qwk(kb_df['accuracy_group'], opt_preds)
# Out:
# 0.5989341057094195

# %%
qwk(kb_df['accuracy_group'][oof != 0], opt_preds)
# Out:
# 0.5754986618584679

# %%
eval_qwk_lgb_regr(kb_df['accuracy_group'][oof != 0], opt_preds)
# Out:
# ('cappa', 0.5327039947764836, True)

# %%
plt.hist(oof[oof != 0], bins=50, alpha=0.2)
plt.hist(opt_preds, bins=50, alpha=0.2, label='opt')
plt.hist(kb_df[oof != 0]['accuracy_group'], bins=50, alpha=0.2, label='label')
plt.legend()
plt.show()

# %%
session_lens = pd.read_pickle('../mnt/inputs/features/train/befTargetCntFeatures.pkl').f019_bef_target_cnt

# %%
plt.scatter(
    session_lens[oof != 0],
    kb_df['accuracy_group'][oof != 0],
    alpha=0.1
)

# %%
test_targets = pd.read_pickle('../mnt/inputs/features/test/targetFeatures.pkl')
test_targets.head()
# Out:
#   installation_id      game_session  num_correct  num_incorrect  \
# 0        00abaee7  8b38fc0d2fd315dc          1.0            0.0
# 0        01242218  009c890ce6c4f3e3          1.0            1.0
# 1        01242218  31423dbcd717919e          1.0            1.0
# 2        01242218  597a8839a5a3468d          1.0            2.0
# 3        01242218  ab61cae5e3215355          0.0            3.0
#
#    accuracy_group
# 0               3
# 0               2
# 1               2
# 2               1
# 3               0

# %%
ls ../mnt/inputs/features/test/
# Out:
# EncodingTitles.pkl  PrevAssessAccByTitle.pkl  immediatelyBeforeFeatures.pkl
# GameDurMiss.pkl     SessionTime2.pkl          worldGameNumeriacalFeatures.pkl
# KernelBasics3.pkl   Worldcount.pkl
# PrevAssessAcc.pkl   befTargetCntFeatures.pkl

# %%
imp_df = pd.read_csv('../mnt/importances/e026.csv')
imp_df.head()
# Out:
#                       feature   importance  fold
# 0                  12 Monkeys     0.000000     0
# 1                    Air Show   538.143310     0
# 2            All Star Sorting  1429.983296     0
# 3               Balancing Act     0.000000     0
# 4  Bird Measurer (Assessment)   636.133198     0

# %%
imp_df.groupby('feature').importance.mean().sort_values(ascending=False).reset_index()
# Out:
#                                          feature    importance
# 0                                      title_enc  95178.224400
# 1                                     as_cum_acc  74850.375048
# 2    title_type_cnt_Crystal Caves - Level 3_Clip  37385.272971
# 3                                    as_prev_acc  26717.439460
# 4                                   cum_accuracy  22991.470853
# ..                                           ...           ...
# 220                         Magma Peak - Level 2      0.000000
# 221                         Magma Peak - Level 1      0.000000
# 222                         Lifting Heavy Things      0.000000
# 223                      Welcome to Lost Lagoon!      0.000000
# 224                                   12 Monkeys      0.000000
#
# [225 rows x 2 columns]

# %%
imp_df.groupby('feature').importance.mean().sort_values(ascending=False).reset_index().head(100)
# Out:
#                                               feature    importance
# 0                                           title_enc  95178.224400
# 1                                          as_cum_acc  74850.375048
# 2         title_type_cnt_Crystal Caves - Level 3_Clip  37385.272971
# 3                                         as_prev_acc  26717.439460
# 4                                        cum_accuracy  22991.470853
# 5                                      accum_acc_gr_0  16984.686164
# 6                    f008_1th_before_session_world_LE  13655.434098
# 7         f013_worldwise_game_world_accracy_mean_mean  11205.344388
# 8                                      as_acc_inc_num   9508.581573
# 9                                        as_acc_c_num   8345.734604
# 10              cum_acc_cum_Chest Sorter (Assessment)   8101.460017
# 11         f013_worldwise_game_world_accracy_max_mean   6471.986206
# 12           cum_acc_cum_Mushroom Sorter (Assessment)   5552.936201
# 13                                 mean_g_misses_mean   5526.085205
# 14         f013_worldwise_game_world_accracy_min_mean   5304.455708
# 15                          Chest Sorter (Assessment)   5301.033300
# 16                                   session_interval   5293.708676
# 17                                mean_g_duration_std   5235.577629
# 18             cum_acc_cum_Cart Balancer (Assessment)   4987.130791
# 19      f013_worldwise_game_TREETOPCITY_accuracy_mean   4968.855166
# 20  f013_worldwise_game_CRYSTALCAVES_just_before_a...   4772.333785
# 21                               session_intervalrmin   4540.789564
# 22                               ass_session_interval   4518.314378
# 23             f008_1th_before_session_game_time_skew   4467.886163
# 24                          prev_ass_gs_duration_rmin   4433.130692
# 25                   f008_1th_before_session_title_LE   4365.849386
# 26     f013_worldwise_game_CRYSTALCAVES_accuracy_mean   4286.751744
# 27                              prev_gs_durationrmean   4120.313032
# 28             cum_acc_cum_Bird Measurer (Assessment)   4075.275410
# 29                              session_intervalrmean   4063.068912
# 30             f008_1th_before_session_game_time_kurt   3980.010546
# 31                               prev_gs_durationrstd   3963.052181
# 32                      wrd_type_cnt_TREETOPCITY_Clip   3931.326225
# 33                          ass_session_interval_rmin   3884.814002
# 34                                    g_duration_mean   3847.346572
# 35                               prev_ass_gs_duration   3826.660322
# 36                         prev_ass_gs_duration_rmean   3743.415928
# 37      f013_worldwise_game_CRYSTALCAVES_accuracy_min   3653.126780
# 38                                     g_duration_std   3652.681732
# 39       f013_worldwise_game_TREETOPCITY_accuracy_min   3595.578130
# 40                                      g_misses_mean   3578.316272
# 41                          prev_ass_gs_duration_rstd   3549.674747
# 42                               session_intervalrmax   3519.055230
# 43                               prev_gs_durationrmax   3515.179558
# 44                               session_intervalrstd   3417.987259
# 45         f013_worldwise_game_world_accracy_std_mean   3346.181636
# 46  f013_worldwise_game_TREETOPCITY_just_before_ac...   3171.891413
# 47            f008_1th_before_session_event_code_last   3171.711165
# 48                                       g_misses_std   3110.510087
# 49                                mean_g_duration_min   3082.626511
# 50                                  mean_g_misses_std   3065.703391
# 51                                     g_duration_min   3018.273894
# 52                          ass_session_interval_rstd   2973.918071
# 53                               mean_g_duration_mean   2927.752422
# 54                                     g_duration_max   2906.957156
# 55                         ass_session_interval_rmean   2902.042526
# 56                                mean_g_duration_max   2895.950152
# 57            f008_1th_before_session_event_count_max   2890.659009
# 58                              mean_g_duration_count   2879.985034
# 59                          prev_ass_gs_duration_rmax   2869.753097
# 60      f013_worldwise_game_CRYSTALCAVES_accuracy_std   2651.616256
# 61                                          Chow Time   2621.237439
# 62                      title_type_cnt_Chow Time_Game   2526.148765
# 63                                wrd_cnt_TREETOPCITY   2525.501404
# 64          f013_worldwise_game_world_accracy_min_std   2519.983355
# 65                     wrd_type_cnt_CRYSTALCAVES_Clip   2459.669104
# 66                                   g_duration_count   2459.315795
# 67                       Cauldron Filler (Assessment)   2412.504240
# 68          f013_worldwise_game_world_accracy_max_std   2341.794784
# 69     cum_num_incorrect_Cauldron Filler (Assessment)   2311.394768
# 70         f013_worldwise_game_MAGMAPEAK_accuracy_std   2291.022568
# 71                      Sandcastle Builder (Activity)   2288.483096
# 72  title_type_cnt_Chest Sorter (Assessment)_Asses...   2264.178385
# 73                                   prev_gs_duration   2249.523679
# 74        f013_worldwise_game_MAGMAPEAK_accuracy_mean   2213.958782
# 75          f013_worldwise_game_world_accracy_min_min   2204.045453
# 76         f013_worldwise_game_world_accracy_mean_std   2141.615992
# 77                        wrd_type_cnt_MAGMAPEAK_Clip   2131.602830
# 78                            Bug Measurer (Activity)   2125.077101
# 79                          ass_session_interval_rmax   2084.247298
# 80       f013_worldwise_game_TREETOPCITY_accuracy_std   2064.428059
# 81                                         Dino Drink   1994.121170
# 82             num_correct_Cart Balancer (Assessment)   1971.266297
# 83  f013_worldwise_game_MAGMAPEAK_just_before_accu...   1943.690491
# 84                  wrd_type_cnt_TREETOPCITY_Activity   1938.865641
# 85                                  mean_g_misses_min   1933.965838
# 86                               wrd_cnt_CRYSTALCAVES   1894.748503
# 87                         Cart Balancer (Assessment)   1863.331713
# 88                                   All Star Sorting   1850.845676
# 89                    title_type_cnt_Happy Camel_Game   1769.060300
# 90  title_type_cnt_Cart Balancer (Assessment)_Asse...   1744.694951
# 91      f013_worldwise_game_CRYSTALCAVES_accuracy_max   1733.596704
# 92  title_type_cnt_Cauldron Filler (Assessment)_As...   1714.430682
# 93                                  mean_g_misses_max   1713.714890
# 94       cum_num_incorrect_Cart Balancer (Assessment)   1711.042662
# 95         f013_worldwise_game_MAGMAPEAK_accuracy_max   1676.204471
# 96                    wrd_type_cnt_MAGMAPEAK_Activity   1660.961960
# 97                          Flower Waterer (Activity)   1643.771043
# 98       f013_worldwise_game_TREETOPCITY_accuracy_max   1636.651567
# 99          f013_worldwise_game_world_accracy_std_std   1633.857766

# %%
imp_df[imp_df.feature.str.contains('prev_gs_duration')]
# Out:
#                     feature   importance  fold
# 118        prev_gs_duration  1604.918631     0
# 120   prev_gs_durationrmean  3223.340843     0
# 121    prev_gs_durationrstd  3410.138787     0
# 122    prev_gs_durationrmax  2962.106423     0
# 123    prev_gs_durationrmin   478.663492     0
# 343        prev_gs_duration  1799.442620     1
# 345   prev_gs_durationrmean  3693.557187     1
# 346    prev_gs_durationrstd  3515.118194     1
# 347    prev_gs_durationrmax  2842.201614     1
# 348    prev_gs_durationrmin   265.381059     1
# 568        prev_gs_duration  2394.932071     2
# 570   prev_gs_durationrmean  4005.586629     2
# 571    prev_gs_durationrstd  4208.890951     2
# 572    prev_gs_durationrmax  3579.347394     2
# 573    prev_gs_durationrmin   421.232891     2
# 793        prev_gs_duration  3144.205568     3
# 795   prev_gs_durationrmean  6134.167070     3
# 796    prev_gs_durationrstd  4772.502593     3
# 797    prev_gs_durationrmax  4425.194710     3
# 798    prev_gs_durationrmin   876.268559     3
# 1018       prev_gs_duration  2304.119504     4
# 1020  prev_gs_durationrmean  3544.913432     4
# 1021   prev_gs_durationrstd  3908.610380     4
# 1022   prev_gs_durationrmax  3767.047647     4
# 1023   prev_gs_durationrmin   480.075071     4

# %%
from sklearn.model_selection import GroupKFold as GKF

gkf = GKF(5)

kb_df = kb_df.reset_index(drop=True)

kb_df['y_preds'] = oof
kb_df['fold'] = None
for fold, (i, j) in enumerate(list(gkf.split(kb_df['installation_id'], kb_df['accuracy_group'], kb_df['installation_id']))):
    kb_df.loc[j, 'fold'] = fold

# %%
for fold in range(5):
    plt.hist(kb_df.query(f'fold == {fold}').y_preds, bins=50, alpha=0.3, label=f'fold : {fold}')
plt.title('y_preds hist of each fold')
plt.legend()
